# %%
#project 6

# %%
import requests
from bs4 import BeautifulSoup
import urllib2 
import time
import json
import pandas as pd
import ijson

#in command line install ijson

# %%
soup = BeautifulSoup(urllib2.urlopen('http://www.imdb.com/chart/top?ref_=ft_250').read())

# %%
#print soup.prettify()

# %%
list_of_movies = []
counter = 0 

for title in soup('td', {'class' : 'titleColumn'}):
    for actual_title in title('a'):
        list_of_movies.append((counter, actual_title.text))
        counter += 1

# %%
for movie in list_of_movies[0:5]:
    print movie
# Out:
# (0, u'The Shawshank Redemption')
# (1, u'The Godfather')
# (2, u'The Godfather: Part II')
# (3, u'The Dark Knight')
# (4, u'12 Angry Men')

# %%
r = requests.get('http://www.omdbapi.com/?type=movie&t=the+shawshank+redemption')

# %%
r.json()
# Out:
# {u'Actors': u'Tim Robbins, Morgan Freeman, Bob Gunton, William Sadler',
#  u'Awards': u'Nominated for 7 Oscars. Another 18 wins & 30 nominations.',
#  u'Country': u'USA',
#  u'Director': u'Frank Darabont',
#  u'Genre': u'Crime, Drama',
#  u'Language': u'English',
#  u'Metascore': u'80',
#  u'Plot': u'Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.',
#  u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BODU4MjU4NjIwNl5BMl5BanBnXkFtZTgwMDU2MjEyMDE@._V1_SX300.jpg',
#  u'Rated': u'R',
#  u'Released': u'14 Oct 1994',
#  u'Response': u'True',
#  u'Runtime': u'142 min',
#  u'Title': u'The Shawshank Redemption',
#  u'Type': u'movie',
#  u'Writer': u'Stephen King (short story "Rita Hayworth and Shawshank Redemption"), Frank Darabont (screenplay)',
#  u'Year': u'1994',
#  u'imdbID': u'tt0111161',
#  u'imdbRating': u'9.3',
#  u'imdbVotes': u'1,711,064'}

# %%
movies_plus_json = []

for movie in list_of_movies[70:80]:
    title = movie[1].replace(' ', '+')
    url = 'http://www.omdbapi.com/?type=movie&t=' + title
    r = requests.get(url)
    movies_plus_json.append((movie[0], r.json()))
    print 'next set'
    time.sleep(1)
# Out:
# next set
# next set
# next set
# next set
# next set
# next set
# next set
# next set
# next set
# next set

# %%
print title
# Out:
# []

# %%
movies_plus_json
# Out:
# [(70,
#   {u'Actors': u'Cary Grant, Eva Marie Saint, James Mason, Jessie Royce Landis',
#    u'Awards': u'Nominated for 3 Oscars. Another 8 wins & 4 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Alfred Hitchcock',
#    u'Genre': u'Action, Adventure, Crime',
#    u'Language': u'English',
#    u'Metascore': u'N/A',
#    u'Plot': u'A hapless New York advertising executive is mistaken for a government agent by a group of foreign spies, and is pursued across the country while he looks for a way to survive.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjQwMTQ0MzgwNl5BMl5BanBnXkFtZTgwNjc4ODE4MzE@._V1_SX300.jpg',
#    u'Rated': u'APPROVED',
#    u'Released': u'26 Sep 1959',
#    u'Response': u'True',
#    u'Runtime': u'136 min',
#    u'Title': u'North by Northwest',
#    u'Type': u'movie',
#    u'Writer': u'Ernest Lehman',
#    u'Year': u'1959',
#    u'imdbID': u'tt0053125',
#    u'imdbRating': u'8.4',
#    u'imdbVotes': u'223,945'}),
#  (71,
#   {u'Actors': u'James Stewart, Kim Novak, Barbara Bel Geddes, Tom Helmore',
#    u'Awards': u'Nominated for 2 Oscars. Another 8 wins & 3 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Alfred Hitchcock',
#    u'Genre': u'Mystery, Romance, Thriller',
#    u'Language': u'English',
#    u'Metascore': u'N/A',
#    u'Plot': u"A San Francisco detective suffering from acrophobia investigates the strange activities of an old friend's wife, all the while becoming dangerously obsessed with her.",
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNzY0NzQyNzQzOF5BMl5BanBnXkFtZTcwMTgwNTk4OQ@@._V1_SX300.jpg',
#    u'Rated': u'PG',
#    u'Released': u'21 Jul 1958',
#    u'Response': u'True',
#    u'Runtime': u'128 min',
#    u'Title': u'Vertigo',
#    u'Type': u'movie',
#    u'Writer': u'Alec Coppel (screenplay), Samuel A. Taylor (screenplay), Pierre Boileau (novel), Thomas Narcejac (novel)',
#    u'Year': u'1958',
#    u'imdbID': u'tt0052357',
#    u'imdbRating': u'8.4',
#    u'imdbVotes': u'254,260'}),
#  (72,
#   {u'Actors': u'Mark Hamill, Harrison Ford, Carrie Fisher, Billy Dee Williams',
#    u'Awards': u'Nominated for 4 Oscars. Another 18 wins & 16 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Richard Marquand',
#    u'Genre': u'Action, Adventure, Fantasy',
#    u'Language': u'English',
#    u'Metascore': u'53',
#    u'Plot': u'After rescuing Han Solo from the palace of Jabba the Hutt, the rebels attempt to destroy the second Death Star, while Luke struggles to make Vader return from the dark side of the Force.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BODllZjg2YjUtNWEzNy00ZGY2LTgyZmQtYTkxNDYyOWM3OTUyXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#    u'Rated': u'PG',
#    u'Released': u'25 May 1983',
#    u'Response': u'True',
#    u'Runtime': u'131 min',
#    u'Title': u'Star Wars: Episode VI - Return of the Jedi',
#    u'Type': u'movie',
#    u'Writer': u'Lawrence Kasdan (screenplay), George Lucas (screenplay), George Lucas (story by)',
#    u'Year': u'1983',
#    u'imdbID': u'tt0086190',
#    u'imdbRating': u'8.4',
#    u'imdbVotes': u'691,701'}),
#  (73,
#   {u'Error': u'Must provide more than one character.', u'Response': u'False'}),
#  (74,
#   {u'Actors': u'Harvey Keitel, Tim Roth, Michael Madsen, Chris Penn',
#    u'Awards': u'9 wins & 15 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Quentin Tarantino',
#    u'Genre': u'Crime, Drama, Thriller',
#    u'Language': u'English',
#    u'Metascore': u'78',
#    u'Plot': u'After a simple jewelry heist goes terribly wrong, the surviving criminals begin to suspect that one of them is a police informant.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNjE5ZDJiZTQtOGE2YS00ZTc5LTk0OGUtOTg2NjdjZmVlYzE2XkEyXkFqcGdeQXVyMzM4MjM0Nzg@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'02 Sep 1992',
#    u'Response': u'True',
#    u'Runtime': u'99 min',
#    u'Title': u'Reservoir Dogs',
#    u'Type': u'movie',
#    u'Writer': u'Quentin Tarantino, Roger Avary (background radio dialog), Quentin Tarantino (background radio dialog)',
#    u'Year': u'1992',
#    u'imdbID': u'tt0105236',
#    u'imdbRating': u'8.4',
#    u'imdbVotes': u'673,300'}),
#  (75,
#   {u'Actors': u'James Robinson, Sean Lawlor, Sandy Nelson, James Cosmo',
#    u'Awards': u'Won 5 Oscars. Another 26 wins & 29 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Mel Gibson',
#    u'Genre': u'Biography, Drama, History',
#    u'Language': u'English, French, Latin, Scottish Gaelic',
#    u'Metascore': u'68',
#    u'Plot': u'When his secret bride is executed for assaulting an English soldier who tried to rape her, William Wallace begins a revolt against King Edward I of England.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNTMyNGE1ODQtYTNiNS00ZTUyLThhZjktMTgyOGZkZThlYTc3XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'24 May 1995',
#    u'Response': u'True',
#    u'Runtime': u'178 min',
#    u'Title': u'Braveheart',
#    u'Type': u'movie',
#    u'Writer': u'Randall Wallace',
#    u'Year': u'1995',
#    u'imdbID': u'tt0112573',
#    u'imdbRating': u'8.4',
#    u'imdbVotes': u'746,574'}),
#  (76,
#   {u'Actors': u'Audrey Tautou, Mathieu Kassovitz, Rufus, Lorella Cravotta',
#    u'Awards': u'Nominated for 5 Oscars. Another 56 wins & 61 nominations.',
#    u'Country': u'France, Germany',
#    u'Director': u'Jean-Pierre Jeunet',
#    u'Genre': u'Comedy, Romance',
#    u'Language': u'French, Russian',
#    u'Metascore': u'69',
#    u'Plot': u'Am\xe9lie is an innocent and naive girl in Paris with her own sense of justice. She decides to help those around her and, along the way, discovers love.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTA3MjVkMWMtYTQ4ZC00ODczLWFjYmQtMDFkZDQ2Y2M0NDVmXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'08 Feb 2002',
#    u'Response': u'True',
#    u'Runtime': u'122 min',
#    u'Title': u'Am\xe9lie',
#    u'Type': u'movie',
#    u'Writer': u'Guillaume Laurant (scenario), Jean-Pierre Jeunet (scenario), Guillaume Laurant (dialogue)',
#    u'Year': u'2001',
#    u'imdbID': u'tt0211915',
#    u'imdbRating': u'8.4',
#    u'imdbVotes': u'544,458'}),
#  (77,
#   {u'Actors': u'Ellen Burstyn, Jared Leto, Jennifer Connelly, Marlon Wayans',
#    u'Awards': u'Nominated for 1 Oscar. Another 32 wins & 61 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Darren Aronofsky',
#    u'Genre': u'Drama',
#    u'Language': u'English',
#    u'Metascore': u'68',
#    u'Plot': u'The drug-induced utopias of four Coney Island people are shattered when their addictions run deep.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTkzODMzODYwOF5BMl5BanBnXkFtZTcwODM2NjA2NQ@@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'15 Dec 2000',
#    u'Response': u'True',
#    u'Runtime': u'102 min',
#    u'Title': u'Requiem for a Dream',
#    u'Type': u'movie',
#    u'Writer': u'Hubert Selby Jr. (based on the book by), Hubert Selby Jr. (screenplay), Darren Aronofsky (screenplay)',
#    u'Year': u'2000',
#    u'imdbID': u'tt0180093',
#    u'imdbRating': u'8.4',
#    u'imdbVotes': u'580,879'}),
#  (78,
#   {u'Actors': u'Malcolm McDowell, Patrick Magee, Michael Bates, Warren Clarke',
#    u'Awards': u'Nominated for 4 Oscars. Another 8 wins & 17 nominations.',
#    u'Country': u'UK, USA',
#    u'Director': u'Stanley Kubrick',
#    u'Genre': u'Crime, Drama, Sci-Fi',
#    u'Language': u'English',
#    u'Metascore': u'78',
#    u'Plot': u"In future Britain, charismatic delinquent Alex DeLarge is jailed and volunteers for an experimental aversion therapy developed by the government in an effort to solve society's crime problem - but not all goes according to plan.",
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTY3MjM1Mzc4N15BMl5BanBnXkFtZTgwODM0NzAxMDE@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'02 Feb 1972',
#    u'Response': u'True',
#    u'Runtime': u'136 min',
#    u'Title': u'A Clockwork Orange',
#    u'Type': u'movie',
#    u'Writer': u'Stanley Kubrick (screenplay), Anthony Burgess (novel)',
#    u'Year': u'1971',
#    u'imdbID': u'tt0066921',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'568,519'}),
#  (79,
#   {u'Actors': u'Diahnne Abbott, Frank Adu, Victor Argo, Gino Ardito',
#    u'Awards': u'Nominated for 4 Oscars. Another 21 wins & 15 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Martin Scorsese',
#    u'Genre': u'Crime, Drama',
#    u'Language': u'English, Spanish',
#    u'Metascore': u'93',
#    u'Plot': u'A mentally unstable Vietnam War veteran works as a night-time taxi driver in New York City where the perceived decadence and sleaze feeds his urge for violent action, attempting to save a preadolescent prostitute in the process.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNGQxNDgzZWQtZTNjNi00M2RkLWExZmEtNmE1NjEyZDEwMzA5XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'08 Feb 1976',
#    u'Response': u'True',
#    u'Runtime': u'113 min',
#    u'Title': u'Taxi Driver',
#    u'Type': u'movie',
#    u'Writer': u'Paul Schrader',
#    u'Year': u'1976',
#    u'imdbID': u'tt0075314',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'515,479'})]

# %%
type(movies_plus_json)
# Out:
# list

# %%
movies_plus_json[0]
# Out:
# (70,
#  {u'Actors': u'Cary Grant, Eva Marie Saint, James Mason, Jessie Royce Landis',
#   u'Awards': u'Nominated for 3 Oscars. Another 8 wins & 4 nominations.',
#   u'Country': u'USA',
#   u'Director': u'Alfred Hitchcock',
#   u'Genre': u'Action, Adventure, Crime',
#   u'Language': u'English',
#   u'Metascore': u'N/A',
#   u'Plot': u'A hapless New York advertising executive is mistaken for a government agent by a group of foreign spies, and is pursued across the country while he looks for a way to survive.',
#   u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjQwMTQ0MzgwNl5BMl5BanBnXkFtZTgwNjc4ODE4MzE@._V1_SX300.jpg',
#   u'Rated': u'APPROVED',
#   u'Released': u'26 Sep 1959',
#   u'Response': u'True',
#   u'Runtime': u'136 min',
#   u'Title': u'North by Northwest',
#   u'Type': u'movie',
#   u'Writer': u'Ernest Lehman',
#   u'Year': u'1959',
#   u'imdbID': u'tt0053125',
#   u'imdbRating': u'8.4',
#   u'imdbVotes': u'223,945'})

# %%
type(movies_plus_json[1])
# Out:
# tuple

# %%
# for item in movies_plus_json[1]:
#         print whatever
#     print '\n'

# %%
title=[]
Rank=[]
Actors=[]
Awards=[]
Country=[]
Director=[]
Genre=[]
Language=[]
Metascore=[]
Plot=[]
Rated=[]
Released=[]
Response=[]
Runtime=[]
Title=[]
Type=[]
Writer=[]
Year=[]
imdbID=[]
imdbRating=[]
imdbVotes=[]

# %%
# for movie in movies_plus_json:
#     Rank.append(str(movie[0]))
#     print 'got to here'
# #    Title.append(movie[1]['Title'])
#     Genre.append(movie[1]['Genre'])
#     Runtime.append(movie[1]['Runtime'].replace(' min', ''))
#     imdbRating.append(movie[1]['imdbRating'])
#     imdbVotes.append(movie[1]['imdbVotes'])
    
    
    
#     for movie in movies_plus_json:
#     print 'ranking is ' + str(movie[0])
#     print 'title is ' + movie[1]['Title']
#     for genre in movie[1]['Genre'].split(','):
#         print 'It has a genre ' + genre.strip()
#     print 'runtime in minutes is ' + movie[1]['Runtime'].replace(' min', '')
#     print movie[1]['imdbRating']
#     print movie[1]['imdbVotes']

# %%
# for movie in movies_plus_json:

#  #   Rank.append(movie[1]['Title'])    
#     Actors.append(movie[1]['Actors'])
#     Awards.append(movie[1]['Awards'])
#     Country.append(movie[1]['Country'])
#     Director.append(movie[1]['Director'])
#     Genre.append(movie[1]['Genre'])
#     Language.append(movie[1]['Language'])
#     Metascore.append(movie[1]['Metascore'])
#     Plot.append(movie[1]['Plot'])
#     Rated.append(movie[1]['Rated'])
#     Released.append(movie[1]['Released'])
#     Response.append(movie[1]['Response'])
#     Runtime.append(movie[1]['Runtime'])
#     Title.append(movie[1]['Title'])
#     Type.append(movie[1]['Type'])
#     Writer.append(movie[1]['Writer'])
#     Year.append(movie[1]['Year'])
#     imdbID.append(movie[1]['imdbID'])
#     imdbRating.append(movie[1]['imdbRating'])
#     imdbVotes.append(movie[1]['imdbVotes'])

# %%
print len(Actors)
print len(Rank)
# Out:
# 0
# 0

# %%
dictMovies={'Ranking':Rank,
     'Actors':Actors,
     'Awards':Awards,
     'Country':Country,
     'Director':Director,
     'Genre':Genre,
     'Language':Language,
     'Metascore':Metascore,
     'Plot':Plot,
     'Rated':Rated,
     'Released':Released,
     'Response':Response,
     'Runtime':Runtime,
     'Title':Title,
     'Type':Type,
     'Writer':Writer,
     'Year':Year,
     'imdbID':imdbID,
     'imdbRating':imdbRating,
     'imdbVotes':imdbVotes}
movieData=pd.DataFrame(dictMovies)

# %%
movies_plus_json
# Out:
# [(70,
#   {u'Actors': u'Cary Grant, Eva Marie Saint, James Mason, Jessie Royce Landis',
#    u'Awards': u'Nominated for 3 Oscars. Another 8 wins & 4 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Alfred Hitchcock',
#    u'Genre': u'Action, Adventure, Crime',
#    u'Language': u'English',
#    u'Metascore': u'N/A',
#    u'Plot': u'A hapless New York advertising executive is mistaken for a government agent by a group of foreign spies, and is pursued across the country while he looks for a way to survive.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjQwMTQ0MzgwNl5BMl5BanBnXkFtZTgwNjc4ODE4MzE@._V1_SX300.jpg',
#    u'Rated': u'APPROVED',
#    u'Released': u'26 Sep 1959',
#    u'Response': u'True',
#    u'Runtime': u'136 min',
#    u'Title': u'North by Northwest',
#    u'Type': u'movie',
#    u'Writer': u'Ernest Lehman',
#    u'Year': u'1959',
#    u'imdbID': u'tt0053125',
#    u'imdbRating': u'8.4',
#    u'imdbVotes': u'223,945'}),
#  (71,
#   {u'Actors': u'James Stewart, Kim Novak, Barbara Bel Geddes, Tom Helmore',
#    u'Awards': u'Nominated for 2 Oscars. Another 8 wins & 3 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Alfred Hitchcock',
#    u'Genre': u'Mystery, Romance, Thriller',
#    u'Language': u'English',
#    u'Metascore': u'N/A',
#    u'Plot': u"A San Francisco detective suffering from acrophobia investigates the strange activities of an old friend's wife, all the while becoming dangerously obsessed with her.",
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNzY0NzQyNzQzOF5BMl5BanBnXkFtZTcwMTgwNTk4OQ@@._V1_SX300.jpg',
#    u'Rated': u'PG',
#    u'Released': u'21 Jul 1958',
#    u'Response': u'True',
#    u'Runtime': u'128 min',
#    u'Title': u'Vertigo',
#    u'Type': u'movie',
#    u'Writer': u'Alec Coppel (screenplay), Samuel A. Taylor (screenplay), Pierre Boileau (novel), Thomas Narcejac (novel)',
#    u'Year': u'1958',
#    u'imdbID': u'tt0052357',
#    u'imdbRating': u'8.4',
#    u'imdbVotes': u'254,260'}),
#  (72,
#   {u'Actors': u'Mark Hamill, Harrison Ford, Carrie Fisher, Billy Dee Williams',
#    u'Awards': u'Nominated for 4 Oscars. Another 18 wins & 16 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Richard Marquand',
#    u'Genre': u'Action, Adventure, Fantasy',
#    u'Language': u'English',
#    u'Metascore': u'53',
#    u'Plot': u'After rescuing Han Solo from the palace of Jabba the Hutt, the rebels attempt to destroy the second Death Star, while Luke struggles to make Vader return from the dark side of the Force.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BODllZjg2YjUtNWEzNy00ZGY2LTgyZmQtYTkxNDYyOWM3OTUyXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#    u'Rated': u'PG',
#    u'Released': u'25 May 1983',
#    u'Response': u'True',
#    u'Runtime': u'131 min',
#    u'Title': u'Star Wars: Episode VI - Return of the Jedi',
#    u'Type': u'movie',
#    u'Writer': u'Lawrence Kasdan (screenplay), George Lucas (screenplay), George Lucas (story by)',
#    u'Year': u'1983',
#    u'imdbID': u'tt0086190',
#    u'imdbRating': u'8.4',
#    u'imdbVotes': u'691,701'}),
#  (73,
#   {u'Error': u'Must provide more than one character.', u'Response': u'False'}),
#  (74,
#   {u'Actors': u'Harvey Keitel, Tim Roth, Michael Madsen, Chris Penn',
#    u'Awards': u'9 wins & 15 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Quentin Tarantino',
#    u'Genre': u'Crime, Drama, Thriller',
#    u'Language': u'English',
#    u'Metascore': u'78',
#    u'Plot': u'After a simple jewelry heist goes terribly wrong, the surviving criminals begin to suspect that one of them is a police informant.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNjE5ZDJiZTQtOGE2YS00ZTc5LTk0OGUtOTg2NjdjZmVlYzE2XkEyXkFqcGdeQXVyMzM4MjM0Nzg@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'02 Sep 1992',
#    u'Response': u'True',
#    u'Runtime': u'99 min',
#    u'Title': u'Reservoir Dogs',
#    u'Type': u'movie',
#    u'Writer': u'Quentin Tarantino, Roger Avary (background radio dialog), Quentin Tarantino (background radio dialog)',
#    u'Year': u'1992',
#    u'imdbID': u'tt0105236',
#    u'imdbRating': u'8.4',
#    u'imdbVotes': u'673,300'}),
#  (75,
#   {u'Actors': u'James Robinson, Sean Lawlor, Sandy Nelson, James Cosmo',
#    u'Awards': u'Won 5 Oscars. Another 26 wins & 29 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Mel Gibson',
#    u'Genre': u'Biography, Drama, History',
#    u'Language': u'English, French, Latin, Scottish Gaelic',
#    u'Metascore': u'68',
#    u'Plot': u'When his secret bride is executed for assaulting an English soldier who tried to rape her, William Wallace begins a revolt against King Edward I of England.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNTMyNGE1ODQtYTNiNS00ZTUyLThhZjktMTgyOGZkZThlYTc3XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'24 May 1995',
#    u'Response': u'True',
#    u'Runtime': u'178 min',
#    u'Title': u'Braveheart',
#    u'Type': u'movie',
#    u'Writer': u'Randall Wallace',
#    u'Year': u'1995',
#    u'imdbID': u'tt0112573',
#    u'imdbRating': u'8.4',
#    u'imdbVotes': u'746,574'}),
#  (76,
#   {u'Actors': u'Audrey Tautou, Mathieu Kassovitz, Rufus, Lorella Cravotta',
#    u'Awards': u'Nominated for 5 Oscars. Another 56 wins & 61 nominations.',
#    u'Country': u'France, Germany',
#    u'Director': u'Jean-Pierre Jeunet',
#    u'Genre': u'Comedy, Romance',
#    u'Language': u'French, Russian',
#    u'Metascore': u'69',
#    u'Plot': u'Am\xe9lie is an innocent and naive girl in Paris with her own sense of justice. She decides to help those around her and, along the way, discovers love.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTA3MjVkMWMtYTQ4ZC00ODczLWFjYmQtMDFkZDQ2Y2M0NDVmXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'08 Feb 2002',
#    u'Response': u'True',
#    u'Runtime': u'122 min',
#    u'Title': u'Am\xe9lie',
#    u'Type': u'movie',
#    u'Writer': u'Guillaume Laurant (scenario), Jean-Pierre Jeunet (scenario), Guillaume Laurant (dialogue)',
#    u'Year': u'2001',
#    u'imdbID': u'tt0211915',
#    u'imdbRating': u'8.4',
#    u'imdbVotes': u'544,458'}),
#  (77,
#   {u'Actors': u'Ellen Burstyn, Jared Leto, Jennifer Connelly, Marlon Wayans',
#    u'Awards': u'Nominated for 1 Oscar. Another 32 wins & 61 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Darren Aronofsky',
#    u'Genre': u'Drama',
#    u'Language': u'English',
#    u'Metascore': u'68',
#    u'Plot': u'The drug-induced utopias of four Coney Island people are shattered when their addictions run deep.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTkzODMzODYwOF5BMl5BanBnXkFtZTcwODM2NjA2NQ@@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'15 Dec 2000',
#    u'Response': u'True',
#    u'Runtime': u'102 min',
#    u'Title': u'Requiem for a Dream',
#    u'Type': u'movie',
#    u'Writer': u'Hubert Selby Jr. (based on the book by), Hubert Selby Jr. (screenplay), Darren Aronofsky (screenplay)',
#    u'Year': u'2000',
#    u'imdbID': u'tt0180093',
#    u'imdbRating': u'8.4',
#    u'imdbVotes': u'580,879'}),
#  (78,
#   {u'Actors': u'Malcolm McDowell, Patrick Magee, Michael Bates, Warren Clarke',
#    u'Awards': u'Nominated for 4 Oscars. Another 8 wins & 17 nominations.',
#    u'Country': u'UK, USA',
#    u'Director': u'Stanley Kubrick',
#    u'Genre': u'Crime, Drama, Sci-Fi',
#    u'Language': u'English',
#    u'Metascore': u'78',
#    u'Plot': u"In future Britain, charismatic delinquent Alex DeLarge is jailed and volunteers for an experimental aversion therapy developed by the government in an effort to solve society's crime problem - but not all goes according to plan.",
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTY3MjM1Mzc4N15BMl5BanBnXkFtZTgwODM0NzAxMDE@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'02 Feb 1972',
#    u'Response': u'True',
#    u'Runtime': u'136 min',
#    u'Title': u'A Clockwork Orange',
#    u'Type': u'movie',
#    u'Writer': u'Stanley Kubrick (screenplay), Anthony Burgess (novel)',
#    u'Year': u'1971',
#    u'imdbID': u'tt0066921',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'568,519'}),
#  (79,
#   {u'Actors': u'Diahnne Abbott, Frank Adu, Victor Argo, Gino Ardito',
#    u'Awards': u'Nominated for 4 Oscars. Another 21 wins & 15 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Martin Scorsese',
#    u'Genre': u'Crime, Drama',
#    u'Language': u'English, Spanish',
#    u'Metascore': u'93',
#    u'Plot': u'A mentally unstable Vietnam War veteran works as a night-time taxi driver in New York City where the perceived decadence and sleaze feeds his urge for violent action, attempting to save a preadolescent prostitute in the process.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNGQxNDgzZWQtZTNjNi00M2RkLWExZmEtNmE1NjEyZDEwMzA5XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'08 Feb 1976',
#    u'Response': u'True',
#    u'Runtime': u'113 min',
#    u'Title': u'Taxi Driver',
#    u'Type': u'movie',
#    u'Writer': u'Paul Schrader',
#    u'Year': u'1976',
#    u'imdbID': u'tt0075314',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'515,479'})]

# %%
for movie in movies_plus_json:
    print 'ranking is ' + str(movie[0])
    print 'title is ' + movie[1]['Title']
    for genre in movie[1]['Genre'].split(','):
        print 'It has a genre ' + genre.strip()
    print 'runtime in minutes is ' + movie[1]['Runtime'].replace(' min', '')
    print movie[1]['imdbRating']
    print movie[1]['imdbVotes']
# Out:
# ranking is 70
# title is North by Northwest
# It has a genre Action
# It has a genre Adventure
# It has a genre Crime
# runtime in minutes is 136
# 8.4
# 223,945
# ranking is 71
# title is Vertigo
# It has a genre Mystery
# It has a genre Romance
# It has a genre Thriller
# runtime in minutes is 128
# 8.4
# 254,260
# ranking is 72
# title is Star Wars: Episode VI - Return of the Jedi
# It has a genre Action
# It has a genre Adventure
# It has a genre Fantasy
# runtime in minutes is 131
# 8.4
# 691,701
# ranking is 73
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-108-6bfca5c7efc3> in <module>()
#       1 for movie in movies_plus_json:
#       2     print 'ranking is ' + str(movie[0])
# ----> 3     print 'title is ' + movie[1]['Title']
#       4     for genre in movie[1]['Genre'].split(','):
#       5         print 'It has a genre ' + genre.strip()
#
# KeyError: 'Title'

# %%
# id: [id="tt1345836|imdb|8.5|8.5|advsearch"] 
#     movie['metascore'] = hxs.xpath('//*[@id="overview-top"]/div[3]/div[3]/a[2
# python_obj = json.loads(movies_plus_json)
# print python_obj["imdbRating"]
# print python_obj["imdbVotes"]

# %%
from imdbpie import Imdb
imdb = Imdb()
imdb = Imdb(anonymize=True) # to proxy requests

# %%
movie = imdb.top_250()

# %%
movie
# Out:
# (73,
#  {u'Error': u'Must provide more than one character.', u'Response': u'False'})

# %%
type(movie)
# Out:
# list

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-112-25f7ee2d2f9e> in <module>()
# ----> 1 for item in movie[0]:
#       2     print item
#
# TypeError: 'int' object is not iterable

# %%
type(movie[0])
# Out:
# dict

# %%
movie[0]['title']
# Out:
# u'The Shawshank Redemption'

# %%
for i in range(0,249):
    title.append(movie[i]['title']) 
    imdbVotes.append(movie[i]['num_votes'])
    imdbRating.append(movie[i]['rating'])
    imdbID.append(movie[i]['tconst'])
    Type.append(movie[i]['type'])
    Year.append(movie[i]['year'])

# %%
print len(title) 
print len(imdbVotes)
print len(imdbRating)
print len(imdbID)
print len(Type)
print len(Year)
# Out:
# 249
# 249
# 249
# 249
# 249
# 249

# %%
Rank=[]
Actors=[]
Awards=[]
Country=[]
Director=[]
Genre=[]
Language=[]
Metascore=[]
Plot=[]
Rated=[]
Released=[]
Response=[]
Runtime=[]
Title=[]
Type=[]
Writer=[]
Year=[]
imdbID=[]
imdbRating=[]
imdbVotes=[]
canRank=[]

# %%
for item in movie:   
    Title.append(movie[1]['title'])    
#     Actors.append(movie[1]['Actors'])
#     Awards.append(movie[1]['Awards'])
#     Country.append(movie[1]['Country'])
#     Director.append(movie[1]['Director'])
    Genre.append(movie[1]['type'])
#     Language.append(movie[1]['Language'])
#     Metascore.append(movie[1]['Metascore'])
#     Plot.append(movie[1]['Plot'])
#     Rated.append(movie[1]['Rated'])
#     Released.append(movie[1]['Released'])
#     Response.append(movie[1]['Response'])
#     Runtime.append(movie[1]['Runtime'])
#     Title.append(movie[1]['Title'])
#     Type.append(movie[1]['Type'])
#     Writer.append(movie[1]['Writer'])
    Year.append(movie[1]['year'])
#    imdbID.append(movie[1]['imdbID'])
    imdbRating.append(movie[1]['rating'])
    imdbVotes.append(movie[1]['num_votes'])

# %%
#imdbRating

# %%
#     print 'ranking is ' + str(movie[0])
# #     if movie[0] == 73:
# #         print movie[1]
#     movieData['Ranking']=movie[1]['Title']
#    # movieData['Title']=(movie[1]['Title'])
#     movieData['Actors'].appendmovie[1]['Actors']
    
#     movieData['Awards']=movie[1]['Awards'],
#     movieData['Country']=movie[1]['Country'],
#     movieData['Director']=movie[1]['Director'],
#     movieData['Genre']=movie[1]['Genre'],
#     movieData['Language']=movie[1]['Language'],
#     movieData['Metascore']=movie[1]['Metascore'],
#     movieData['Plot']=movie[1]['Plot'],
#     movieData['Rated']=movie[1]['Rated'],
#     movieData['Released']=movie[1]['Released'],
#     movieData['Response']=movie[1]['Response'],
#     movieData['Runtime']=movie[1]['Runtime'],
#     movieData['Type']=movie[1]['Type'],
#     movieData['Writer']=movie[1]['Writer'],
#     movieData['Year']=movie[1]['Year'],
#     movieData['imdbID']=movie[1]['imdbID'],
#     movieData['imdbRating']=movie[1]['imdbRating'],
#     movieData['imdbVotes']=movie[1]['imdbVotes'],

# %%
#list_of_movies

# %%
movies3_plus_json=[]


for movie in list_of_movies[74:249]:
    title = movie[1].replace(' ', '+')
    url = 'http://www.omdbapi.com/?type=movie&t=' + title
    r = requests.get(url)
    movies3_plus_json.append((movie[0], r.json()))
    time.sleep(1)

# %%
movies3_plus_json
# Out:
# [(74,
#   {u'Actors': u'Harvey Keitel, Tim Roth, Michael Madsen, Chris Penn',
#    u'Awards': u'9 wins & 15 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Quentin Tarantino',
#    u'Genre': u'Crime, Drama, Thriller',
#    u'Language': u'English',
#    u'Metascore': u'78',
#    u'Plot': u'After a simple jewelry heist goes terribly wrong, the surviving criminals begin to suspect that one of them is a police informant.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNjE5ZDJiZTQtOGE2YS00ZTc5LTk0OGUtOTg2NjdjZmVlYzE2XkEyXkFqcGdeQXVyMzM4MjM0Nzg@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'02 Sep 1992',
#    u'Response': u'True',
#    u'Runtime': u'99 min',
#    u'Title': u'Reservoir Dogs',
#    u'Type': u'movie',
#    u'Writer': u'Quentin Tarantino, Roger Avary (background radio dialog), Quentin Tarantino (background radio dialog)',
#    u'Year': u'1992',
#    u'imdbID': u'tt0105236',
#    u'imdbRating': u'8.4',
#    u'imdbVotes': u'673,300'}),
#  (75,
#   {u'Actors': u'James Robinson, Sean Lawlor, Sandy Nelson, James Cosmo',
#    u'Awards': u'Won 5 Oscars. Another 26 wins & 29 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Mel Gibson',
#    u'Genre': u'Biography, Drama, History',
#    u'Language': u'English, French, Latin, Scottish Gaelic',
#    u'Metascore': u'68',
#    u'Plot': u'When his secret bride is executed for assaulting an English soldier who tried to rape her, William Wallace begins a revolt against King Edward I of England.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNTMyNGE1ODQtYTNiNS00ZTUyLThhZjktMTgyOGZkZThlYTc3XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'24 May 1995',
#    u'Response': u'True',
#    u'Runtime': u'178 min',
#    u'Title': u'Braveheart',
#    u'Type': u'movie',
#    u'Writer': u'Randall Wallace',
#    u'Year': u'1995',
#    u'imdbID': u'tt0112573',
#    u'imdbRating': u'8.4',
#    u'imdbVotes': u'746,574'}),
#  (76,
#   {u'Actors': u'Audrey Tautou, Mathieu Kassovitz, Rufus, Lorella Cravotta',
#    u'Awards': u'Nominated for 5 Oscars. Another 56 wins & 61 nominations.',
#    u'Country': u'France, Germany',
#    u'Director': u'Jean-Pierre Jeunet',
#    u'Genre': u'Comedy, Romance',
#    u'Language': u'French, Russian',
#    u'Metascore': u'69',
#    u'Plot': u'Am\xe9lie is an innocent and naive girl in Paris with her own sense of justice. She decides to help those around her and, along the way, discovers love.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTA3MjVkMWMtYTQ4ZC00ODczLWFjYmQtMDFkZDQ2Y2M0NDVmXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'08 Feb 2002',
#    u'Response': u'True',
#    u'Runtime': u'122 min',
#    u'Title': u'Am\xe9lie',
#    u'Type': u'movie',
#    u'Writer': u'Guillaume Laurant (scenario), Jean-Pierre Jeunet (scenario), Guillaume Laurant (dialogue)',
#    u'Year': u'2001',
#    u'imdbID': u'tt0211915',
#    u'imdbRating': u'8.4',
#    u'imdbVotes': u'544,458'}),
#  (77,
#   {u'Actors': u'Ellen Burstyn, Jared Leto, Jennifer Connelly, Marlon Wayans',
#    u'Awards': u'Nominated for 1 Oscar. Another 32 wins & 61 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Darren Aronofsky',
#    u'Genre': u'Drama',
#    u'Language': u'English',
#    u'Metascore': u'68',
#    u'Plot': u'The drug-induced utopias of four Coney Island people are shattered when their addictions run deep.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTkzODMzODYwOF5BMl5BanBnXkFtZTcwODM2NjA2NQ@@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'15 Dec 2000',
#    u'Response': u'True',
#    u'Runtime': u'102 min',
#    u'Title': u'Requiem for a Dream',
#    u'Type': u'movie',
#    u'Writer': u'Hubert Selby Jr. (based on the book by), Hubert Selby Jr. (screenplay), Darren Aronofsky (screenplay)',
#    u'Year': u'2000',
#    u'imdbID': u'tt0180093',
#    u'imdbRating': u'8.4',
#    u'imdbVotes': u'580,879'}),
#  (78,
#   {u'Actors': u'Malcolm McDowell, Patrick Magee, Michael Bates, Warren Clarke',
#    u'Awards': u'Nominated for 4 Oscars. Another 8 wins & 17 nominations.',
#    u'Country': u'UK, USA',
#    u'Director': u'Stanley Kubrick',
#    u'Genre': u'Crime, Drama, Sci-Fi',
#    u'Language': u'English',
#    u'Metascore': u'78',
#    u'Plot': u"In future Britain, charismatic delinquent Alex DeLarge is jailed and volunteers for an experimental aversion therapy developed by the government in an effort to solve society's crime problem - but not all goes according to plan.",
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTY3MjM1Mzc4N15BMl5BanBnXkFtZTgwODM0NzAxMDE@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'02 Feb 1972',
#    u'Response': u'True',
#    u'Runtime': u'136 min',
#    u'Title': u'A Clockwork Orange',
#    u'Type': u'movie',
#    u'Writer': u'Stanley Kubrick (screenplay), Anthony Burgess (novel)',
#    u'Year': u'1971',
#    u'imdbID': u'tt0066921',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'568,519'}),
#  (79,
#   {u'Actors': u'Diahnne Abbott, Frank Adu, Victor Argo, Gino Ardito',
#    u'Awards': u'Nominated for 4 Oscars. Another 21 wins & 15 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Martin Scorsese',
#    u'Genre': u'Crime, Drama',
#    u'Language': u'English, Spanish',
#    u'Metascore': u'93',
#    u'Plot': u'A mentally unstable Vietnam War veteran works as a night-time taxi driver in New York City where the perceived decadence and sleaze feeds his urge for violent action, attempting to save a preadolescent prostitute in the process.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNGQxNDgzZWQtZTNjNi00M2RkLWExZmEtNmE1NjEyZDEwMzA5XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'08 Feb 1976',
#    u'Response': u'True',
#    u'Runtime': u'113 min',
#    u'Title': u'Taxi Driver',
#    u'Type': u'movie',
#    u'Writer': u'Paul Schrader',
#    u'Year': u'1976',
#    u'imdbID': u'tt0075314',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'515,479'}),
#  (80,
#   {u'Actors': u'Fred MacMurray, Barbara Stanwyck, Edward G. Robinson, Porter Hall',
#    u'Awards': u'Nominated for 7 Oscars. Another 2 wins & 2 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Billy Wilder',
#    u'Genre': u'Crime, Drama, Film-Noir',
#    u'Language': u'English',
#    u'Metascore': u'N/A',
#    u'Plot': u"An insurance representative lets himself be talked into a murder/insurance fraud scheme that arouses an insurance investigator's suspicions.",
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTQzOTE4MTIzMV5BMl5BanBnXkFtZTgwODc1NDQ5MDE@._V1_SX300.jpg',
#    u'Rated': u'PASSED',
#    u'Released': u'24 Apr 1944',
#    u'Response': u'True',
#    u'Runtime': u'107 min',
#    u'Title': u'Double Indemnity',
#    u'Type': u'movie',
#    u'Writer': u'Billy Wilder (screenplay), Raymond Chandler (screenplay), James M. Cain (from the novel by)',
#    u'Year': u'1944',
#    u'imdbID': u'tt0036775',
#    u'imdbRating': u'8.4',
#    u'imdbVotes': u'99,468'}),
#  (81,
#   {u'Actors': u"Peter O'Toole, Alec Guinness, Anthony Quinn, Jack Hawkins",
#    u'Awards': u'Won 7 Oscars. Another 23 wins & 14 nominations.',
#    u'Country': u'UK, USA',
#    u'Director': u'David Lean',
#    u'Genre': u'Adventure, Biography, Drama',
#    u'Language': u'English, Arabic, Turkish',
#    u'Metascore': u'100',
#    u'Plot': u'The story of T.E. Lawrence, the English officer who successfully united and lead the diverse, often warring, Arab tribes during World War I in order to fight the Turks.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BYWY5ZjhjNGYtZmI2Ny00ODM0LWFkNzgtZmI1YzA2N2MxMzA0XkEyXkFqcGdeQXVyNjUwNzk3NDc@._V1_SX300.jpg',
#    u'Rated': u'PG',
#    u'Released': u'11 Dec 1962',
#    u'Response': u'True',
#    u'Runtime': u'216 min',
#    u'Title': u'Lawrence of Arabia',
#    u'Type': u'movie',
#    u'Writer': u'T.E. Lawrence (writings), Robert Bolt (screenplay), Michael Wilson (screenplay)',
#    u'Year': u'1962',
#    u'imdbID': u'tt0056172',
#    u'imdbRating': u'8.4',
#    u'imdbVotes': u'195,496'}),
#  (82,
#   {u'Actors': u'Gregory Peck, John Megna, Frank Overton, Rosemary Murphy',
#    u'Awards': u'Won 3 Oscars. Another 10 wins & 16 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Robert Mulligan',
#    u'Genre': u'Crime, Drama',
#    u'Language': u'English',
#    u'Metascore': u'N/A',
#    u'Plot': u'Atticus Finch, a lawyer in the Depression-era South, defends a black man against an undeserved rape charge, and his kids against prejudice.',
#    u'Poster': u'http://ia.media-imdb.com/images/M/MV5BMjA4MzI1NDY2Nl5BMl5BanBnXkFtZTcwMTcyODc5Mw@@._V1_SX300.jpg',
#    u'Rated': u'NOT RATED',
#    u'Released': u'16 Mar 1963',
#    u'Response': u'True',
#    u'Runtime': u'129 min',
#    u'Title': u'To Kill a Mockingbird',
#    u'Type': u'movie',
#    u'Writer': u'Harper Lee (based on her novel "To Kill a Mockingbird"), Horton Foote (screenplay)',
#    u'Year': u'1962',
#    u'imdbID': u'tt0056592',
#    u'imdbRating': u'8.4',
#    u'imdbVotes': u'214,957'}),
#  (83,
#   {u'Actors': u'Tom Hanks, Tim Allen, Joan Cusack, Ned Beatty',
#    u'Awards': u'Won 2 Oscars. Another 58 wins & 89 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Lee Unkrich',
#    u'Genre': u'Animation, Adventure, Comedy',
#    u'Language': u'English, Spanish',
#    u'Metascore': u'92',
#    u'Plot': u"The toys are mistakenly delivered to a day-care center instead of the attic right before Andy leaves for college, and it's up to Woody to convince the other toys that they weren't abandoned and to return home.",
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTgxOTY4Mjc0MF5BMl5BanBnXkFtZTcwNTA4MDQyMw@@._V1_SX300.jpg',
#    u'Rated': u'G',
#    u'Released': u'18 Jun 2010',
#    u'Response': u'True',
#    u'Runtime': u'103 min',
#    u'Title': u'Toy Story 3',
#    u'Type': u'movie',
#    u'Writer': u'John Lasseter (story by), Andrew Stanton (story by), Lee Unkrich (story by), Michael Arndt (screenplay)',
#    u'Year': u'2010',
#    u'imdbID': u'tt0435761',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'555,480'}),
#  (84,
#   {u'Actors': u'Jim Carrey, Kate Winslet, Gerry Robert Byrne, Elijah Wood',
#    u'Awards': u'Won 1 Oscar. Another 67 wins & 103 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Michel Gondry',
#    u'Genre': u'Drama, Fantasy, Romance',
#    u'Language': u'English',
#    u'Metascore': u'89',
#    u'Plot': u'When their relationship turns sour, a couple undergoes a procedure to have each other erased from their memories. But it is only through the process of loss that they discover what they had to begin with.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTY4NzcwODg3Nl5BMl5BanBnXkFtZTcwNTEwOTMyMw@@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'19 Mar 2004',
#    u'Response': u'True',
#    u'Runtime': u'108 min',
#    u'Title': u'Eternal Sunshine of the Spotless Mind',
#    u'Type': u'movie',
#    u'Writer': u'Charlie Kaufman (story), Michel Gondry (story), Pierre Bismuth (story), Charlie Kaufman (screenplay)',
#    u'Year': u'2004',
#    u'imdbID': u'tt0338013',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'677,332'}),
#  (85,
#   {u'Actors': u'F. Murray Abraham, Tom Hulce, Elizabeth Berridge, Roy Dotrice',
#    u'Awards': u'Won 8 Oscars. Another 33 wins & 14 nominations.',
#    u'Country': u'USA, France',
#    u'Director': u'Milos Forman',
#    u'Genre': u'Biography, Drama, History',
#    u'Language': u'English, Italian, Latin, German',
#    u'Metascore': u'93',
#    u'Plot': u'The incredible story of Wolfgang Amadeus Mozart, told by his peer and secret rival Antonio Salieri - now confined to an insane asylum.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTg5NDkwMTk5N15BMl5BanBnXkFtZTYwODg3MDk2._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'19 Sep 1984',
#    u'Response': u'True',
#    u'Runtime': u'160 min',
#    u'Title': u'Amadeus',
#    u'Type': u'movie',
#    u'Writer': u'Peter Shaffer (original stage play), Peter Shaffer (original screenplay)',
#    u'Year': u'1984',
#    u'imdbID': u'tt0086879',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'275,620'}),
#  (86,
#   {u'Actors': u"Matthew Modine, Adam Baldwin, Vincent D'Onofrio, R. Lee Ermey",
#    u'Awards': u'Nominated for 1 Oscar. Another 7 wins & 9 nominations.',
#    u'Country': u'UK, USA',
#    u'Director': u'Stanley Kubrick',
#    u'Genre': u'Drama, War',
#    u'Language': u'English, Vietnamese',
#    u'Metascore': u'78',
#    u'Plot': u'A pragmatic U.S. Marine observes the dehumanizing effects the Vietnam War has on his fellow recruits from their brutal boot camp training to the bloody street fighting in Hue.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjA4NzY4ODk4Nl5BMl5BanBnXkFtZTgwOTcxNTYxMTE@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'10 Jul 1987',
#    u'Response': u'True',
#    u'Runtime': u'116 min',
#    u'Title': u'Full Metal Jacket',
#    u'Type': u'movie',
#    u'Writer': u'Gustav Hasford (novel), Stanley Kubrick (screenplay), Michael Herr (screenplay), Gustav Hasford (screenplay)',
#    u'Year': u'1987',
#    u'imdbID': u'tt0093058',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'492,386'}),
#  (87,
#   {u'Actors': u'Paul Newman, Robert Redford, Robert Shaw, Charles Durning',
#    u'Awards': u'Won 7 Oscars. Another 10 wins & 6 nominations.',
#    u'Country': u'USA',
#    u'Director': u'George Roy Hill',
#    u'Genre': u'Comedy, Crime, Drama',
#    u'Language': u'English',
#    u'Metascore': u'N/A',
#    u'Plot': u'In Chicago in September 1936, a young con man seeking revenge for his murdered partner teams up with a master of the big con to win a fortune from a criminal banker.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTY5MjM1OTAyOV5BMl5BanBnXkFtZTgwMDkwODg4MDE@._V1._CR52,57,915,1388_SX89_AL_.jpg_V1_SX300.jpg',
#    u'Rated': u'PG',
#    u'Released': u'25 Dec 1973',
#    u'Response': u'True',
#    u'Runtime': u'129 min',
#    u'Title': u'The Sting',
#    u'Type': u'movie',
#    u'Writer': u'David S. Ward',
#    u'Year': u'1973',
#    u'imdbID': u'tt0070735',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'178,734'}),
#  (88,
#   {u'Actors': u'Keir Dullea, Gary Lockwood, William Sylvester, Daniel Richter',
#    u'Awards': u'Won 1 Oscar. Another 13 wins & 7 nominations.',
#    u'Country': u'UK, USA',
#    u'Director': u'Stanley Kubrick',
#    u'Genre': u'Adventure, Mystery, Sci-Fi',
#    u'Language': u'English, Russian',
#    u'Metascore': u'86',
#    u'Plot': u'Humanity finds a mysterious, obviously artificial object buried beneath the Lunar surface and, with the intelligent computer H.A.L. 9000, sets off on a quest.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTZkZTBhYmUtMTIzNy00YTViLTg1OWItNGUwMmVlN2FjZTVkXkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_SX300.jpg',
#    u'Rated': u'G',
#    u'Released': u'12 May 1968',
#    u'Response': u'True',
#    u'Runtime': u'149 min',
#    u'Title': u'2001: A Space Odyssey',
#    u'Type': u'movie',
#    u'Writer': u'Stanley Kubrick (screenplay), Arthur C. Clarke (screenplay)',
#    u'Year': u'1968',
#    u'imdbID': u'tt0062622',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'433,823'}),
#  (89,
#   {u'Actors': u'Lamberto Maggiorani, Enzo Staiola, Lianella Carell, Gino Saltamerenda',
#    u'Awards': u'Nominated for 1 Oscar. Another 18 wins.',
#    u'Country': u'Italy',
#    u'Director': u'Vittorio De Sica',
#    u'Genre': u'Drama',
#    u'Language': u'Italian',
#    u'Metascore': u'N/A',
#    u'Plot': u"Set in Post-WWII Italy, a working class man's bicycle is stolen. He and his son set out to find it.",
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjIzMzAyMzg1Nl5BMl5BanBnXkFtZTgwMzMyNzk0MTE@._V1_SX300.jpg',
#    u'Rated': u'NOT RATED',
#    u'Released': u'13 Dec 1949',
#    u'Response': u'True',
#    u'Runtime': u'89 min',
#    u'Title': u'Bicycle Thieves',
#    u'Type': u'movie',
#    u'Writer': u"Cesare Zavattini (story), Luigi Bartolini (novel), Oreste Biancoli (screenplay), Suso Cecchi D'Amico (screenplay), Vittorio De Sica (screenplay), Adolfo Franci (screenplay), Gherardo Gherardi (screenplay), Gerardo Guerrieri (screenplay), Cesare Zavattini (screenplay)",
#    u'Year': u'1948',
#    u'imdbID': u'tt0040522',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'96,195'}),
#  (90,
#   {u'Actors': u'Tom Hanks, Tim Allen, Don Rickles, Jim Varney',
#    u'Awards': u'Nominated for 3 Oscars. Another 23 wins & 18 nominations.',
#    u'Country': u'USA',
#    u'Director': u'John Lasseter',
#    u'Genre': u'Animation, Adventure, Comedy',
#    u'Language': u'English',
#    u'Metascore': u'92',
#    u'Plot': u"A cowboy doll is profoundly threatened and jealous when a new spaceman figure supplants him as top toy in a boy's room.",
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMDU2ZWJlMjktMTRhMy00ZTA5LWEzNDgtYmNmZTEwZTViZWJkXkEyXkFqcGdeQXVyNDQ2OTk4MzI@._V1_SX300.jpg',
#    u'Rated': u'G',
#    u'Released': u'22 Nov 1995',
#    u'Response': u'True',
#    u'Runtime': u'81 min',
#    u'Title': u'Toy Story',
#    u'Type': u'movie',
#    u'Writer': u'John Lasseter (original story by), Pete Docter (original story by), Andrew Stanton (original story by), Joe Ranft (original story by), Joss Whedon (screenplay), Andrew Stanton (screenplay), Joel Cohen (screenplay), Alec Sokolow (screenplay)',
#    u'Year': u'1995',
#    u'imdbID': u'tt0114709',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'634,074'}),
#  (91,
#   {u'Actors': u'Benicio Del Toro, Dennis Farina, Vinnie Jones, Brad Pitt',
#    u'Awards': u'4 wins & 6 nominations.',
#    u'Country': u'UK, USA',
#    u'Director': u'Guy Ritchie',
#    u'Genre': u'Comedy, Crime',
#    u'Language': u'English, Russian',
#    u'Metascore': u'55',
#    u'Plot': u'Unscrupulous boxing promoters, violent bookmakers, a Russian gangster, incompetent amateur robbers, and supposedly Jewish jewelers fight to track down a priceless stolen diamond.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTA2NDYxOGYtYjU1Mi00Y2QzLTgxMTQtMWI1MGI0ZGQ5MmU4XkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'19 Jan 2001',
#    u'Response': u'True',
#    u'Runtime': u'102 min',
#    u'Title': u'Snatch',
#    u'Type': u'movie',
#    u'Writer': u'Guy Ritchie',
#    u'Year': u'2000',
#    u'imdbID': u'tt0208092',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'611,594'}),
#  (92,
#   {u'Actors': u"Gene Kelly, Donald O'Connor, Debbie Reynolds, Jean Hagen",
#    u'Awards': u'Nominated for 2 Oscars. Another 5 wins & 7 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Stanley Donen, Gene Kelly',
#    u'Genre': u'Comedy, Musical, Romance',
#    u'Language': u'English',
#    u'Metascore': u'N/A',
#    u'Plot': u'A silent film production company and cast make a difficult transition to sound.',
#    u'Poster': u'http://ia.media-imdb.com/images/M/MV5BMTUxMTIyNTI4Nl5BMl5BanBnXkFtZTcwNTk1ODQyMg@@._V1_SX300.jpg',
#    u'Rated': u'APPROVED',
#    u'Released': u'11 Apr 1952',
#    u'Response': u'True',
#    u'Runtime': u'103 min',
#    u'Title': u"Singin' in the Rain",
#    u'Type': u'movie',
#    u'Writer': u'Betty Comden (story by), Adolph Green (story by)',
#    u'Year': u'1952',
#    u'imdbID': u'tt0045152',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'151,178'}),
#  (93,
#   {u'Actors': u'Brad Pitt, M\xe9lanie Laurent, Christoph Waltz, Eli Roth',
#    u'Awards': u'Won 1 Oscar. Another 124 wins & 153 nominations.',
#    u'Country': u'USA, Germany',
#    u'Director': u'Quentin Tarantino, Eli Roth',
#    u'Genre': u'Adventure, Drama, War',
#    u'Language': u'English, German, French, Italian',
#    u'Metascore': u'69',
#    u'Plot': u"In Nazi-occupied France during World War II, a plan to assassinate Nazi leaders by a group of Jewish U.S. soldiers coincides with a theatre owner's vengeful plans for the same.",
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BOTJiNDEzOWYtMTVjOC00ZjlmLWE0NGMtZmE1OWVmZDQ2OWJhXkEyXkFqcGdeQXVyNTIzOTk5ODM@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'21 Aug 2009',
#    u'Response': u'True',
#    u'Runtime': u'153 min',
#    u'Title': u'Inglourious Basterds',
#    u'Type': u'movie',
#    u'Writer': u'Quentin Tarantino',
#    u'Year': u'2009',
#    u'imdbID': u'tt0361748',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'900,274'}),
#  (94,
#   {u'Actors': u'Carl Miller, Edna Purviance, Jackie Coogan, Charles Chaplin',
#    u'Awards': u'1 win.',
#    u'Country': u'USA',
#    u'Director': u'Charles Chaplin',
#    u'Genre': u'Comedy, Drama, Family',
#    u'Language': u'English',
#    u'Metascore': u'N/A',
#    u'Plot': u'The Tramp cares for an abandoned child, but events put that relationship in jeopardy.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNjE4MWM3MDctOTk2NC00MTUwLTg2OTUtYjg5YWU3MzRmYTg0XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#    u'Rated': u'NOT RATED',
#    u'Released': u'06 Feb 1921',
#    u'Response': u'True',
#    u'Runtime': u'68 min',
#    u'Title': u'The Kid',
#    u'Type': u'movie',
#    u'Writer': u'Charles Chaplin',
#    u'Year': u'1921',
#    u'imdbID': u'tt0012349',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'68,817'}),
#  (95,
#   {u'Actors': u'Graham Chapman, John Cleese, Eric Idle, Terry Gilliam',
#    u'Awards': u'2 wins & 2 nominations.',
#    u'Country': u'UK',
#    u'Director': u'Terry Gilliam, Terry Jones',
#    u'Genre': u'Adventure, Comedy, Fantasy',
#    u'Language': u'English, French, Latin',
#    u'Metascore': u'90',
#    u'Plot': u'King Arthur and his knights embark on a low-budget search for the Grail, encountering many, very silly obstacles.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BYzgyYzc4Y2QtNDcyZS00NDdmLWI5ZTYtMTQ2YWU5MWFhOTE4XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#    u'Rated': u'PG',
#    u'Released': u'25 May 1975',
#    u'Response': u'True',
#    u'Runtime': u'91 min',
#    u'Title': u'Monty Python and the Holy Grail',
#    u'Type': u'movie',
#    u'Writer': u'Graham Chapman, John Cleese, Eric Idle, Terry Gilliam, Terry Jones, Michael Palin',
#    u'Year': u'1975',
#    u'imdbID': u'tt0071853',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'387,820'}),
#  (96,
#   {u'Actors': u'Kevin Spacey, Russell Crowe, Guy Pearce, James Cromwell',
#    u'Awards': u'Won 2 Oscars. Another 84 wins & 77 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Curtis Hanson',
#    u'Genre': u'Crime, Drama, Mystery',
#    u'Language': u'English',
#    u'Metascore': u'90',
#    u'Plot': u'As corruption grows in 1950s LA, three policemen - one strait-laced, one brutal, and one sleazy - investigate a series of murders with their own brand of justice.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNWEwNDhhNWUtYWMzNi00ZTNhLWFiZDAtMjBjZmJhMTU0ZTY2XkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'19 Sep 1997',
#    u'Response': u'True',
#    u'Runtime': u'138 min',
#    u'Title': u'L.A. Confidential',
#    u'Type': u'movie',
#    u'Writer': u'James Ellroy (novel), Brian Helgeland (screenplay), Curtis Hanson (screenplay)',
#    u'Year': u'1997',
#    u'imdbID': u'tt0119488',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'419,413'}),
#  (97,
#   {u'Actors': u'Clint Eastwood, Lee Van Cleef, Gian Maria Volont\xe8, Mario Brega',
#    u'Awards': u'N/A',
#    u'Country': u'Italy, Spain, West Germany',
#    u'Director': u'Sergio Leone',
#    u'Genre': u'Western',
#    u'Language': u'Italian',
#    u'Metascore': u'N/A',
#    u'Plot': u'Two bounty hunters with the same intentions team up to track down a Western outlaw.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTQzMjIzOTEzMF5BMl5BanBnXkFtZTcwMTUzNTk3NA@@._V1_SX300.jpg',
#    u'Rated': u'APPROVED',
#    u'Released': u'10 May 1967',
#    u'Response': u'True',
#    u'Runtime': u'132 min',
#    u'Title': u'For a Few Dollars More',
#    u'Type': u'movie',
#    u'Writer': u'Sergio Leone (scenario), Fulvio Morsella (scenario), Luciano Vincenzoni (screenplay), Sergio Leone (screenplay), Luciano Vincenzoni (dialogue: English version)',
#    u'Year': u'1965',
#    u'imdbID': u'tt0059578',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'160,493'}),
#  (98,
#   {u'Actors': u'Omenosuke Ichikawa, Setsuko Kai, Yoshiko Kashiwa, Yuzuru Kume',
#    u'Awards': u'N/A',
#    u'Country': u'Japan',
#    u'Director': u'Shinzo Yoshida',
#    u'Genre': u'Mystery',
#    u'Language': u'Japanese',
#    u'Metascore': u'N/A',
#    u'Plot': u'N/A',
#    u'Poster': u'N/A',
#    u'Rated': u'N/A',
#    u'Released': u'08 May 1941',
#    u'Response': u'True',
#    u'Runtime': u'N/A',
#    u'Title': u'Rash\xf4mon',
#    u'Type': u'movie',
#    u'Writer': u'Chikayoshi Tange (based on the novel by), Chikayoshi Tange (screenplay)',
#    u'Year': u'1941',
#    u'imdbID': u'tt2759632',
#    u'imdbRating': u'N/A',
#    u'imdbVotes': u'N/A'}),
#  (99,
#   {u'Actors': u'Aamir Khan, Madhavan, Sharman Joshi, Kareena Kapoor',
#    u'Awards': u'25 wins & 13 nominations.',
#    u'Country': u'India',
#    u'Director': u'Rajkumar Hirani',
#    u'Genre': u'Comedy, Drama',
#    u'Language': u'Hindi, English',
#    u'Metascore': u'67',
#    u'Plot': u'Two friends are searching for their long lost companion. They revisit their college days and recall the memories of their friend who inspired them to think differently, even as the rest of the world called them "idiots".',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTMyOTg0ODQ1OF5BMl5BanBnXkFtZTcwNjc0NTMwNQ@@._V1_SX300.jpg',
#    u'Rated': u'PG-13',
#    u'Released': u'25 Dec 2009',
#    u'Response': u'True',
#    u'Runtime': u'170 min',
#    u'Title': u'3 Idiots',
#    u'Type': u'movie',
#    u'Writer': u'Rajkumar Hirani (screenplay), Abhijat Joshi (screenplay), Vidhu Vinod Chopra (screenplay), Abhijat Joshi (story), Chetan Bhagat (novel)',
#    u'Year': u'2009',
#    u'imdbID': u'tt1187043',
#    u'imdbRating': u'8.4',
#    u'imdbVotes': u'213,636'}),
#  (100,
#   {u'Actors': u'Jack Lemmon, Shirley MacLaine, Fred MacMurray, Ray Walston',
#    u'Awards': u'Won 5 Oscars. Another 19 wins & 8 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Billy Wilder',
#    u'Genre': u'Comedy, Drama, Romance',
#    u'Language': u'English',
#    u'Metascore': u'N/A',
#    u'Plot': u'A man tries to rise in his company by letting its executives use his apartment for trysts, but complications and a romance of his own ensue.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTM1OTc4MzgzNl5BMl5BanBnXkFtZTcwNTE2NjgyMw@@._V1_SX300.jpg',
#    u'Rated': u'APPROVED',
#    u'Released': u'16 Sep 1960',
#    u'Response': u'True',
#    u'Runtime': u'125 min',
#    u'Title': u'The Apartment',
#    u'Type': u'movie',
#    u'Writer': u'Billy Wilder, I.A.L. Diamond',
#    u'Year': u'1960',
#    u'imdbID': u'tt0053604',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'111,667'}),
#  (101,
#   {u'Actors': u'Al Pacino, Steven Bauer, Michelle Pfeiffer, Mary Elizabeth Mastrantonio',
#    u'Awards': u'Nominated for 3 Golden Globes. Another 4 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Brian De Palma',
#    u'Genre': u'Crime, Drama',
#    u'Language': u'English, Spanish',
#    u'Metascore': u'65',
#    u'Plot': u'In Miami in 1980, a determined Cuban immigrant takes over a drug cartel and succumbs to greed.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjAzOTM4MzEwNl5BMl5BanBnXkFtZTgwMzU1OTc1MDE@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'09 Dec 1983',
#    u'Response': u'True',
#    u'Runtime': u'170 min',
#    u'Title': u'Scarface',
#    u'Type': u'movie',
#    u'Writer': u'Oliver Stone (screenplay)',
#    u'Year': u'1983',
#    u'imdbID': u'tt0086250',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'544,522'}),
#  (102,
#   {u'Actors': u'Harrison Ford, Sean Connery, Denholm Elliott, Alison Doody',
#    u'Awards': u'Won 1 Oscar. Another 6 wins & 20 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Steven Spielberg',
#    u'Genre': u'Action, Adventure, Fantasy',
#    u'Language': u'English, German, Greek, Arabic',
#    u'Metascore': u'65',
#    u'Plot': u"When Dr. Henry Jones Sr. suddenly goes missing while pursuing the Holy Grail, eminent archaeologist Indiana Jones must follow in his father's footsteps and stop the Nazis.",
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjNkMzc2N2QtNjVlNS00ZTk5LTg0MTgtODY2MDAwNTMwZjBjXkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_SX300.jpg',
#    u'Rated': u'PG-13',
#    u'Released': u'24 May 1989',
#    u'Response': u'True',
#    u'Runtime': u'127 min',
#    u'Title': u'Indiana Jones and the Last Crusade',
#    u'Type': u'movie',
#    u'Writer': u'Jeffrey Boam (screenplay), George Lucas (story), Menno Meyjes (story), George Lucas (characters), Philip Kaufman (characters)',
#    u'Year': u'1989',
#    u'imdbID': u'tt0097576',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'522,489'}),
#  (103, {u'Error': u'Movie not found!', u'Response': u'False'}),
#  (104,
#   {u'Actors': u'Alfred Abel, Gustav Fr\xf6hlich, Rudolf Klein-Rogge, Fritz Rasp',
#    u'Awards': u'4 wins & 4 nominations.',
#    u'Country': u'Germany',
#    u'Director': u'Fritz Lang',
#    u'Genre': u'Drama, Sci-Fi',
#    u'Language': u'German',
#    u'Metascore': u'98',
#    u'Plot': u"In a futuristic city sharply divided between the working class and the city planners, the son of the city's mastermind falls in love with a working class prophet who predicts the coming of a savior to mediate their differences.",
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNDAzNTkyODg1MF5BMl5BanBnXkFtZTgwMDA3NDkwMDE@._V1_SX300.jpg',
#    u'Rated': u'NOT RATED',
#    u'Released': u'13 Mar 1927',
#    u'Response': u'True',
#    u'Runtime': u'153 min',
#    u'Title': u'Metropolis',
#    u'Type': u'movie',
#    u'Writer': u'Thea von Harbou (screenplay), Thea von Harbou (novel)',
#    u'Year': u'1927',
#    u'imdbID': u'tt0017136',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'113,363'}),
#  (105,
#   {u'Actors': u'Lars Hjortsh\xf8j, Camilla Bendix, Mille Dinesen, Rune Tolsgaard',
#    u'Awards': u'3 nominations.',
#    u'Country': u'Denmark',
#    u'Director': u'S\xf8ren Frellesen',
#    u'Genre': u'Adventure',
#    u'Language': u'Danish',
#    u'Metascore': u'N/A',
#    u'Plot': u'N/A',
#    u'Poster': u'http://ia.media-imdb.com/images/M/MV5BMTg2NzcwMjQ3Nl5BMl5BanBnXkFtZTgwNTA5MzUyNzE@._V1_SX300.jpg',
#    u'Rated': u'N/A',
#    u'Released': u'12 Nov 2015',
#    u'Response': u'True',
#    u'Runtime': u'91 min',
#    u'Title': u'Emma & Julemanden: Jagten p\xe5 elverdronningens hjerte',
#    u'Type': u'movie',
#    u'Writer': u'Philip LaZebnik, Jenny Lund Madsen, Uffe R\xf8rb\xe6k Madsen',
#    u'Year': u'2015',
#    u'imdbID': u'tt4819154',
#    u'imdbRating': u'6.0',
#    u'imdbVotes': u'23'}),
#  (106,
#   {u'Actors': u'Matt Damon, Robin Williams, Ben Affleck, Stellan Skarsg\xe5rd',
#    u'Awards': u'Won 2 Oscars. Another 20 wins & 53 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Gus Van Sant',
#    u'Genre': u'Drama',
#    u'Language': u'English',
#    u'Metascore': u'70',
#    u'Plot': u'Will Hunting, a janitor at M.I.T., has a gift for mathematics, but needs help from a psychologist to find direction in his life.',
#    u'Poster': u'http://ia.media-imdb.com/images/M/MV5BMTk0NjY0Mzg5MF5BMl5BanBnXkFtZTcwNzM1OTM2MQ@@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'09 Jan 1998',
#    u'Response': u'True',
#    u'Runtime': u'126 min',
#    u'Title': u'Good Will Hunting',
#    u'Type': u'movie',
#    u'Writer': u'Matt Damon, Ben Affleck',
#    u'Year': u'1997',
#    u'imdbID': u'tt0119217',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'609,983'}),
#  (107,
#   {u'Actors': u'Bette Davis, Anne Baxter, George Sanders, Celeste Holm',
#    u'Awards': u'Won 6 Oscars. Another 16 wins & 17 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Joseph L. Mankiewicz',
#    u'Genre': u'Drama',
#    u'Language': u'English, French',
#    u'Metascore': u'N/A',
#    u'Plot': u'An ingenue insinuates herself into the company of an established but aging stage actress and her circle of theater friends.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTY2MTAzODI5NV5BMl5BanBnXkFtZTgwMjM4NzQ0MjE@._V1_SX300.jpg',
#    u'Rated': u'APPROVED',
#    u'Released': u'15 Jan 1951',
#    u'Response': u'True',
#    u'Runtime': u'138 min',
#    u'Title': u'All About Eve',
#    u'Type': u'movie',
#    u'Writer': u'Joseph L. Mankiewicz (written for the screen by)',
#    u'Year': u'1950',
#    u'imdbID': u'tt0042192',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'84,353'}),
#  (108,
#   {u'Actors': u'Toshir\xf4 Mifune, Tatsuya Nakadai, Y\xf4ko Tsukasa, Isuzu Yamada',
#    u'Awards': u'Nominated for 1 Oscar. Another 4 wins & 1 nomination.',
#    u'Country': u'Japan',
#    u'Director': u'Akira Kurosawa',
#    u'Genre': u'Action, Drama, Thriller',
#    u'Language': u'Japanese',
#    u'Metascore': u'N/A',
#    u'Plot': u'A crafty ronin comes to a town divided by two criminal gangs and decides to play them against each other to free the town.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjAwNTQ3ODUyMl5BMl5BanBnXkFtZTgwNDg5ODQyNjE@._V1_SX300.jpg',
#    u'Rated': u'UNRATED',
#    u'Released': u'13 Sep 1961',
#    u'Response': u'True',
#    u'Runtime': u'110 min',
#    u'Title': u'Yojimbo',
#    u'Type': u'movie',
#    u'Writer': u'Akira Kurosawa (story), Akira Kurosawa (screenplay), Ry\xfbz\xf4 Kikushima (screenplay)',
#    u'Year': u'1961',
#    u'imdbID': u'tt0055630',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'75,317'}),
#  (109,
#   {u'Actors': u'Christian Bale, Michael Caine, Liam Neeson, Katie Holmes',
#    u'Awards': u'Nominated for 1 Oscar. Another 15 wins & 66 nominations.',
#    u'Country': u'USA, UK',
#    u'Director': u'Christopher Nolan',
#    u'Genre': u'Action, Adventure',
#    u'Language': u'English, Urdu, Mandarin',
#    u'Metascore': u'70',
#    u'Plot': u'After training with his mentor, Batman begins his fight to free crime-ridden Gotham City from the corruption that Scarecrow and the League of Shadows have cast upon it.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNTM3OTc0MzM2OV5BMl5BanBnXkFtZTYwNzUwMTI3._V1_SX300.jpg',
#    u'Rated': u'PG-13',
#    u'Released': u'15 Jun 2005',
#    u'Response': u'True',
#    u'Runtime': u'140 min',
#    u'Title': u'Batman Begins',
#    u'Type': u'movie',
#    u'Writer': u'Bob Kane (characters), David S. Goyer (story), Christopher Nolan (screenplay), David S. Goyer (screenplay)',
#    u'Year': u'2005',
#    u'imdbID': u'tt0372784',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'1,000,101'}),
#  (110,
#   {u'Actors': u'Humphrey Bogart, Walter Huston, Tim Holt, Bruce Bennett',
#    u'Awards': u'Won 3 Oscars. Another 12 wins & 5 nominations.',
#    u'Country': u'USA',
#    u'Director': u'John Huston',
#    u'Genre': u'Adventure, Drama, Western',
#    u'Language': u'English, Spanish',
#    u'Metascore': u'N/A',
#    u'Plot': u'Fred Dobbs and Bob Curtin, two Americans searching for work in Mexico, convince an old prospector to help them mine for gold in the Sierra Madre Mountains.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTQ4MzUzOTYwOV5BMl5BanBnXkFtZTgwNDA4MzgyMjE@._V1_SX300.jpg',
#    u'Rated': u'APPROVED',
#    u'Released': u'24 Jan 1948',
#    u'Response': u'True',
#    u'Runtime': u'126 min',
#    u'Title': u'The Treasure of the Sierra Madre',
#    u'Type': u'movie',
#    u'Writer': u'John Huston (screenplay), B. Traven (based on the novel by)',
#    u'Year': u'1948',
#    u'imdbID': u'tt0040897',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'80,571'}),
#  (111,
#   {u'Actors': u'Marilyn Monroe, Tony Curtis, Jack Lemmon, George Raft',
#    u'Awards': u'Won 1 Oscar. Another 9 wins & 13 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Billy Wilder',
#    u'Genre': u'Comedy, Romance',
#    u'Language': u'English',
#    u'Metascore': u'N/A',
#    u'Plot': u'When two male musicians witness a mob hit, they flee the state in an all-female band disguised as women, but further complications set in.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BY2JlMWQ2M2QtMjgwYy00MzY3LTg5ZTgtYjc2OTA5MWFkNGMyXkEyXkFqcGdeQXVyNjc0MzMzNjA@._V1_SX300.jpg',
#    u'Rated': u'NOT RATED',
#    u'Released': u'14 Apr 1959',
#    u'Response': u'True',
#    u'Runtime': u'120 min',
#    u'Title': u'Some Like It Hot',
#    u'Type': u'movie',
#    u'Writer': u'Billy Wilder (screenplay), I.A.L. Diamond (screenplay), Robert Thoeren (suggested by a story by), Michael Logan (suggested by a story by)',
#    u'Year': u'1959',
#    u'imdbID': u'tt0053291',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'177,841'}),
#  (112,
#   {u'Actors': u'Edward Asner, Christopher Plummer, Jordan Nagai, Bob Peterson',
#    u'Awards': u'Won 2 Oscars. Another 73 wins & 75 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Pete Docter, Bob Peterson',
#    u'Genre': u'Animation, Adventure, Comedy',
#    u'Language': u'English',
#    u'Metascore': u'88',
#    u'Plot': u'Seventy-eight year old Carl Fredricksen travels to Paradise Falls in his home equipped with balloons, inadvertently taking a young stowaway.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTk3NDE2NzI4NF5BMl5BanBnXkFtZTgwNzE1MzEyMTE@._V1_SX300.jpg',
#    u'Rated': u'PG',
#    u'Released': u'29 May 2009',
#    u'Response': u'True',
#    u'Runtime': u'96 min',
#    u'Title': u'Up',
#    u'Type': u'movie',
#    u'Writer': u'Pete Docter (story by), Bob Peterson (story by), Tom McCarthy (story by), Bob Peterson (screenplay), Pete Docter (screenplay)',
#    u'Year': u'2009',
#    u'imdbID': u'tt1049413',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'676,319'}),
#  (113,
#   {u'Actors': u'Clint Eastwood, Gene Hackman, Morgan Freeman, Richard Harris',
#    u'Awards': u'Won 4 Oscars. Another 36 wins & 29 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Clint Eastwood',
#    u'Genre': u'Drama, Western',
#    u'Language': u'English',
#    u'Metascore': u'82',
#    u'Plot': u'Retired Old West gunslinger William Munny reluctantly takes on one last job, with the help of his old partner and a young man.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BODM3YWY4NmQtN2Y3Ni00OTg0LWFhZGQtZWE3ZWY4MTJlOWU4XkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'07 Aug 1992',
#    u'Response': u'True',
#    u'Runtime': u'131 min',
#    u'Title': u'Unforgiven',
#    u'Type': u'movie',
#    u'Writer': u'David Webb Peoples',
#    u'Year': u'1992',
#    u'imdbID': u'tt0105695',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'281,356'}),
#  (114,
#   {u'Actors': u'Joseph Cotten, Alida Valli, Orson Welles, Trevor Howard',
#    u'Awards': u'Won 1 Oscar. Another 4 wins & 4 nominations.',
#    u'Country': u'UK',
#    u'Director': u'Carol Reed',
#    u'Genre': u'Film-Noir, Mystery, Thriller',
#    u'Language': u'English, German, Russian',
#    u'Metascore': u'N/A',
#    u'Plot': u'Pulp novelist Holly Martins travels to shadowy, postwar Vienna, only to find himself investigating the mysterious death of an old friend, Harry Lime.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjMwNzMzMTQ0Ml5BMl5BanBnXkFtZTgwNjExMzUwNjE@._V1_SX300.jpg',
#    u'Rated': u'NOT RATED',
#    u'Released': u'31 Aug 1949',
#    u'Response': u'True',
#    u'Runtime': u'93 min',
#    u'Title': u'The Third Man',
#    u'Type': u'movie',
#    u'Writer': u'Graham Greene (by), Graham Greene (screen play)',
#    u'Year': u'1949',
#    u'imdbID': u'tt0041959',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'115,046'}),
#  (115,
#   {u'Actors': u'Bruno Ganz, Alexandra Maria Lara, Corinna Harfouch, Ulrich Matthes',
#    u'Awards': u'Nominated for 1 Oscar. Another 21 wins & 25 nominations.',
#    u'Country': u'Germany, Austria, Italy',
#    u'Director': u'Oliver Hirschbiegel',
#    u'Genre': u'Biography, Drama, History',
#    u'Language': u'German, Russian, Hungarian',
#    u'Metascore': u'82',
#    u'Plot': u"Traudl Junge, the final secretary for Adolf Hitler, tells of the Nazi dictator's final days in his Berlin bunker at the end of WWII.",
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTM1OTI1MjE2Nl5BMl5BanBnXkFtZTcwMTEwMzc4NA@@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'08 Apr 2005',
#    u'Response': u'True',
#    u'Runtime': u'156 min',
#    u'Title': u'Downfall',
#    u'Type': u'movie',
#    u'Writer': u'Bernd Eichinger (screenplay), Joachim Fest (book), Traudl Junge (book), Melissa M\xfcller (book)',
#    u'Year': u'2004',
#    u'imdbID': u'tt0363163',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'252,695'}),
#  (116,
#   {u'Actors': u'Robert De Niro, Cathy Moriarty, Joe Pesci, Frank Vincent',
#    u'Awards': u'Won 2 Oscars. Another 22 wins & 24 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Martin Scorsese',
#    u'Genre': u'Biography, Drama, Sport',
#    u'Language': u'English',
#    u'Metascore': u'92',
#    u'Plot': u"An emotionally self-destructive boxer's journey through life, as the violence and temper that leads him to the top in the ring destroys his life outside it.",
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjIxOTg3OTc5MF5BMl5BanBnXkFtZTcwNzkwNjMwNA@@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'19 Dec 1980',
#    u'Response': u'True',
#    u'Runtime': u'129 min',
#    u'Title': u'Raging Bull',
#    u'Type': u'movie',
#    u'Writer': u'Jake LaMotta (based on the book by), Joseph Carter (with), Peter Savage (with), Paul Schrader (screenplay), Mardik Martin (screenplay)',
#    u'Year': u'1980',
#    u'imdbID': u'tt0081398',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'238,964'}),
#  (117,
#   {u'Actors': u'Bruce Willis, Bonnie Bedelia, Reginald VelJohnson, Paul Gleason',
#    u'Awards': u'Nominated for 4 Oscars. Another 6 wins & 2 nominations.',
#    u'Country': u'USA',
#    u'Director': u'John McTiernan',
#    u'Genre': u'Action, Thriller',
#    u'Language': u'English, German, Italian',
#    u'Metascore': u'70',
#    u'Plot': u'John McClane, officer of the NYPD, tries to save his wife Holly Gennaro and several others that were taken hostage by German terrorist Hans Gruber during a Christmas party at the Nakatomi Plaza in Los Angeles.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BYmY2ZGEwMTYtNjBmZS00OGE4LWEyMmUtNjAwMWUxZjVmZTRiXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'20 Jul 1988',
#    u'Response': u'True',
#    u'Runtime': u'131 min',
#    u'Title': u'Die Hard',
#    u'Type': u'movie',
#    u'Writer': u'Roderick Thorp (novel), Jeb Stuart (screenplay), Steven E. de Souza (screenplay)',
#    u'Year': u'1988',
#    u'imdbID': u'tt0095016',
#    u'imdbRating': u'8.2',
#    u'imdbVotes': u'599,179'}),
#  (118,
#   {u'Actors': u'Mohammad Amir Naji, Amir Farrokh Hashemian, Bahare Seddiqi, Nafise Jafar-Mohammadi',
#    u'Awards': u'Nominated for 1 Oscar. Another 13 wins & 4 nominations.',
#    u'Country': u'Iran',
#    u'Director': u'Majid Majidi',
#    u'Genre': u'Drama, Family',
#    u'Language': u'Persian',
#    u'Metascore': u'N/A',
#    u'Plot': u'After a boy loses his sister\'s pair of shoes, he goes on a series of adventures in order to find them. When he can\'t, he tries a new way to "win" a new pair.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTg0OTk4MDEwMV5BMl5BanBnXkFtZTYwNzMwNzI5._V1_SX300.jpg',
#    u'Rated': u'PG',
#    u'Released': u'22 Jan 1999',
#    u'Response': u'True',
#    u'Runtime': u'89 min',
#    u'Title': u'Children of Heaven',
#    u'Type': u'movie',
#    u'Writer': u'Majid Majidi',
#    u'Year': u'1997',
#    u'imdbID': u'tt0118849',
#    u'imdbRating': u'8.4',
#    u'imdbVotes': u'29,750'}),
#  (119,
#   {u'Actors': u'Steve McQueen, James Garner, Richard Attenborough, James Donald',
#    u'Awards': u'Nominated for 1 Oscar. Another 2 wins & 7 nominations.',
#    u'Country': u'USA',
#    u'Director': u'John Sturges',
#    u'Genre': u'Adventure, Drama, History',
#    u'Language': u'English, German, French, Russian, Spanish',
#    u'Metascore': u'N/A',
#    u'Plot': u'Allied P.O.W.s plan for several hundred of their number to escape from a German camp during World War II.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjI2MTQwNDI3Nl5BMl5BanBnXkFtZTcwNDk4MTkzNA@@._V1_SX300.jpg',
#    u'Rated': u'APPROVED',
#    u'Released': u'04 Jul 1963',
#    u'Response': u'True',
#    u'Runtime': u'172 min',
#    u'Title': u'The Great Escape',
#    u'Type': u'movie',
#    u'Writer': u'Paul Brickhill (book), James Clavell (screenplay), W.R. Burnett (screenplay)',
#    u'Year': u'1963',
#    u'imdbID': u'tt0057115',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'167,926'}),
#  (120,
#   {u'Actors': u'Al Pacino, Robert De Niro, Val Kilmer, Jon Voight',
#    u'Awards': u'12 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Michael Mann',
#    u'Genre': u'Action, Crime, Drama',
#    u'Language': u'English, Spanish',
#    u'Metascore': u'76',
#    u'Plot': u'A group of professional bank robbers start to feel the heat from police when they unknowingly leave a clue at their latest heist.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNGMwNzUwNjYtZWM5NS00YzMyLWI4NjAtNjM0ZDBiMzE1YWExXkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'15 Dec 1995',
#    u'Response': u'True',
#    u'Runtime': u'170 min',
#    u'Title': u'Heat',
#    u'Type': u'movie',
#    u'Writer': u'Michael Mann',
#    u'Year': u'1995',
#    u'imdbID': u'tt0113277',
#    u'imdbRating': u'8.2',
#    u'imdbVotes': u'437,583'}),
#  (121,
#   {u'Actors': u'Jack Nicholson, Faye Dunaway, John Huston, Perry Lopez',
#    u'Awards': u'Won 1 Oscar. Another 20 wins & 23 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Roman Polanski',
#    u'Genre': u'Drama, Mystery, Thriller',
#    u'Language': u'English, Cantonese, Spanish',
#    u'Metascore': u'86',
#    u'Plot': u'A private detective hired to expose an adulterer finds himself caught up in a web of deceit, corruption and murder.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BN2YyNDE5NzItMjAwNC00MGQxLTllNjktZGIzMWFkZjA3OWQ0XkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'20 Jun 1974',
#    u'Response': u'True',
#    u'Runtime': u'130 min',
#    u'Title': u'Chinatown',
#    u'Type': u'movie',
#    u'Writer': u'Robert Towne',
#    u'Year': u'1974',
#    u'imdbID': u'tt0071315',
#    u'imdbRating': u'8.2',
#    u'imdbVotes': u'220,193'}),
#  (122,
#   {u'Actors': u'Amy Poehler, Phyllis Smith, Richard Kind, Bill Hader',
#    u'Awards': u'Won 1 Oscar. Another 91 wins & 95 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Pete Docter, Ronnie Del Carmen',
#    u'Genre': u'Animation, Adventure, Comedy',
#    u'Language': u'English',
#    u'Metascore': u'94',
#    u'Plot': u'After young Riley is uprooted from her Midwest life and moved to San Francisco, her emotions - Joy, Fear, Anger, Disgust and Sadness - conflict on how best to navigate a new city, house, and school.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BOTgxMDQwMDk0OF5BMl5BanBnXkFtZTgwNjU5OTg2NDE@._V1_SX300.jpg',
#    u'Rated': u'PG',
#    u'Released': u'19 Jun 2015',
#    u'Response': u'True',
#    u'Runtime': u'95 min',
#    u'Title': u'Inside Out',
#    u'Type': u'movie',
#    u'Writer': u'Pete Docter (original story by), Ronnie Del Carmen (original story by), Pete Docter (screenplay), Meg LeFauve (screenplay), Josh Cooley (screenplay), Michael Arndt (additional story material by), Bill Hader (additional dialogue by), Amy Poehler (additional dialogue by), Simon Rich (additional story material by)',
#    u'Year': u'2015',
#    u'imdbID': u'tt2096673',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'360,055'}),
#  (123,
#   {u'Actors': u'Ivana Baquero, Sergi L\xf3pez, Maribel Verd\xfa, Doug Jones',
#    u'Awards': u'Won 3 Oscars. Another 94 wins & 99 nominations.',
#    u'Country': u'Spain, Mexico, USA',
#    u'Director': u'Guillermo del Toro',
#    u'Genre': u'Drama, Fantasy, War',
#    u'Language': u'Spanish',
#    u'Metascore': u'98',
#    u'Plot': u'In the falangist Spain of 1944, the bookish young stepdaughter of a sadistic army officer escapes into an eerie but captivating fantasy world.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTU3ODg2NjQ5NF5BMl5BanBnXkFtZTcwMDEwODgzMQ@@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'19 Jan 2007',
#    u'Response': u'True',
#    u'Runtime': u'118 min',
#    u'Title': u"Pan's Labyrinth",
#    u'Type': u'movie',
#    u'Writer': u'Guillermo del Toro',
#    u'Year': u'2006',
#    u'imdbID': u'tt0457430',
#    u'imdbRating': u'8.2',
#    u'imdbVotes': u'475,029'}),
#  (124,
#   {u'Actors': u'Marlon Brando, Karl Malden, Lee J. Cobb, Rod Steiger',
#    u'Awards': u'Won 8 Oscars. Another 21 wins & 9 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Elia Kazan',
#    u'Genre': u'Crime, Drama, Thriller',
#    u'Language': u'English',
#    u'Metascore': u'88',
#    u'Plot': u'An ex-prize fighter turned longshoreman struggles to stand up to his corrupt union bosses.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTcwMTU3MjI1OV5BMl5BanBnXkFtZTgwNjE2OTI3MjE@._V1_SX300.jpg',
# ...
#    u'Type': u'movie',
#    u'Writer': u'Akhilesh Jaiswal, Anurag Kashyap, Sachin K. Ladia, Zeishan Quadri',
#    u'Year': u'2012',
#    u'imdbID': u'tt1954470',
#    u'imdbRating': u'8.3',
#    u'imdbVotes': u'48,140'}),
#  (232,
#   {u'Actors': u'Leonardo DiCaprio, Tom Hardy, Domhnall Gleeson, Will Poulter',
#    u'Awards': u'Won 3 Oscars. Another 75 wins & 160 nominations.',
#    u'Country': u'USA, Hong Kong, Taiwan',
#    u'Director': u'Alejandro G. I\xf1\xe1rritu',
#    u'Genre': u'Adventure, Drama, Thriller',
#    u'Language': u'English, Pawnee, French',
#    u'Metascore': u'76',
#    u'Plot': u'A frontiersman on a fur trading expedition in the 1820s fights for survival after being mauled by a bear and left for dead by members of his own hunting team.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjU4NDExNDM1NF5BMl5BanBnXkFtZTgwMDIyMTgxNzE@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'08 Jan 2016',
#    u'Response': u'True',
#    u'Runtime': u'156 min',
#    u'Title': u'The Revenant',
#    u'Type': u'movie',
#    u'Writer': u'Mark L. Smith (screenplay), Alejandro G. I\xf1\xe1rritu (screenplay), Michael Punke (based in part on the novel by)',
#    u'Year': u'2015',
#    u'imdbID': u'tt1663202',
#    u'imdbRating': u'8.1',
#    u'imdbVotes': u'432,094'}),
#  (233,
#   {u'Actors': u'Johnny Depp, Geoffrey Rush, Orlando Bloom, Keira Knightley',
#    u'Awards': u'Nominated for 5 Oscars. Another 31 wins & 88 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Gore Verbinski',
#    u'Genre': u'Action, Adventure, Fantasy',
#    u'Language': u'English',
#    u'Metascore': u'63',
#    u'Plot': u'Blacksmith Will Turner teams up with eccentric pirate "Captain" Jack Sparrow to save his love, the governor\'s daughter, from Jack\'s former pirate allies, who are now undead.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjAyNDM4MTc2N15BMl5BanBnXkFtZTYwNDk0Mjc3._V1_SX300.jpg',
#    u'Rated': u'PG-13',
#    u'Released': u'09 Jul 2003',
#    u'Response': u'True',
#    u'Runtime': u'143 min',
#    u'Title': u'Pirates of the Caribbean: The Curse of the Black Pearl',
#    u'Type': u'movie',
#    u'Writer': u'Ted Elliott (screen story), Terry Rossio (screen story), Stuart Beattie (screen story), Jay Wolpert (screen story), Ted Elliott (screenplay), Terry Rossio (screenplay)',
#    u'Year': u'2003',
#    u'imdbID': u'tt0325980',
#    u'imdbRating': u'8.1',
#    u'imdbVotes': u'819,105'}),
#  (234,
#   {u'Actors': u'Emma Stone, Viola Davis, Bryce Dallas Howard, Octavia Spencer',
#    u'Awards': u'Won 1 Oscar. Another 79 wins & 112 nominations.',
#    u'Country': u'USA, India, United Arab Emirates',
#    u'Director': u'Tate Taylor',
#    u'Genre': u'Drama',
#    u'Language': u'English',
#    u'Metascore': u'62',
#    u'Plot': u"An aspiring author during the civil rights movement of the 1960s decides to write a book detailing the African American maids' point of view on the white families for which they work, and the hardships they go through on a daily basis.",
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTM5OTMyMjIxOV5BMl5BanBnXkFtZTcwNzU4MjIwNQ@@._V1_SX300.jpg',
#    u'Rated': u'PG-13',
#    u'Released': u'10 Aug 2011',
#    u'Response': u'True',
#    u'Runtime': u'146 min',
#    u'Title': u'The Help',
#    u'Type': u'movie',
#    u'Writer': u'Tate Taylor (screenplay), Kathryn Stockett (novel)',
#    u'Year': u'2011',
#    u'imdbID': u'tt1454029',
#    u'imdbRating': u'8.1',
#    u'imdbVotes': u'323,265'}),
#  (235,
#   {u'Actors': u'Benedict Cumberbatch, Keira Knightley, Matthew Goode, Rory Kinnear',
#    u'Awards': u'Won 1 Oscar. Another 44 wins & 150 nominations.',
#    u'Country': u'UK, USA',
#    u'Director': u'Morten Tyldum',
#    u'Genre': u'Biography, Drama, Thriller',
#    u'Language': u'English, German',
#    u'Metascore': u'73',
#    u'Plot': u'During World War II, mathematician Alan Turing tries to crack the enigma code with help from fellow mathematicians.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNDkwNTEyMzkzNl5BMl5BanBnXkFtZTgwNTAwNzk3MjE@._V1_SX300.jpg',
#    u'Rated': u'PG-13',
#    u'Released': u'25 Dec 2014',
#    u'Response': u'True',
#    u'Runtime': u'114 min',
#    u'Title': u'The Imitation Game',
#    u'Type': u'movie',
#    u'Writer': u'Graham Moore, Andrew Hodges (book)',
#    u'Year': u'2014',
#    u'imdbID': u'tt2084970',
#    u'imdbRating': u'8.1',
#    u'imdbVotes': u'480,890'}),
#  (236,
#   {u'Actors': u'David Rawle, Brendan Gleeson, Lisa Hannigan, Fionnula Flanagan',
#    u'Awards': u'Nominated for 1 Oscar. Another 11 wins & 20 nominations.',
#    u'Country': u'Ireland, Denmark, Belgium, Luxembourg, France',
#    u'Director': u'Tomm Moore',
#    u'Genre': u'Animation, Adventure, Family',
#    u'Language': u'English, Irish, Scottish Gaelic',
#    u'Metascore': u'85',
#    u'Plot': u'Ben, a young Irish boy, and his little sister Saoirse, a girl who can turn into a seal, go on an adventure to free the faeries and save the spirit world.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTQ2MDMwNjEwNV5BMl5BanBnXkFtZTgwOTkxMzI0MzE@._V1_SX300.jpg',
#    u'Rated': u'PG',
#    u'Released': u'10 Dec 2014',
#    u'Response': u'True',
#    u'Runtime': u'93 min',
#    u'Title': u'Song of the Sea',
#    u'Type': u'movie',
#    u'Writer': u'Will Collins, Tomm Moore (story by)',
#    u'Year': u'2014',
#    u'imdbID': u'tt1865505',
#    u'imdbRating': u'8.2',
#    u'imdbVotes': u'26,560'}),
#  (237, {u'Error': u'Movie not found!', u'Response': u'False'}),
#  (238,
#   {u'Actors': u'Ryan Reynolds, Karan Soni, Ed Skrein, Michael Benyaer',
#    u'Awards': u'4 wins & 11 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Tim Miller',
#    u'Genre': u'Action, Adventure, Comedy',
#    u'Language': u'English',
#    u'Metascore': u'65',
#    u'Plot': u'A fast-talking mercenary with a morbid sense of humor is subjected to a rogue experiment that leaves him with accelerated healing powers and a quest for revenge.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjQyODg5Njc4N15BMl5BanBnXkFtZTgwMzExMjE3NzE@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'12 Feb 2016',
#    u'Response': u'True',
#    u'Runtime': u'108 min',
#    u'Title': u'Deadpool',
#    u'Type': u'movie',
#    u'Writer': u'Rhett Reese, Paul Wernick',
#    u'Year': u'2016',
#    u'imdbID': u'tt1431045',
#    u'imdbRating': u'8.1',
#    u'imdbVotes': u'530,311'}),
#  (239,
#   {u'Actors': u'Matt Damon, Jessica Chastain, Kristen Wiig, Jeff Daniels',
#    u'Awards': u'Nominated for 7 Oscars. Another 34 wins & 171 nominations.',
#    u'Country': u'USA, UK',
#    u'Director': u'Ridley Scott',
#    u'Genre': u'Adventure, Drama, Sci-Fi',
#    u'Language': u'English, Mandarin',
#    u'Metascore': u'80',
#    u'Plot': u'An astronaut becomes stranded on Mars after his team assume him dead, and must rely on his ingenuity to find a way to signal to Earth that he is alive.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTc2MTQ3MDA1Nl5BMl5BanBnXkFtZTgwODA3OTI4NjE@._V1_SX300.jpg',
#    u'Rated': u'PG-13',
#    u'Released': u'02 Oct 2015',
#    u'Response': u'True',
#    u'Runtime': u'144 min',
#    u'Title': u'The Martian',
#    u'Type': u'movie',
#    u'Writer': u'Drew Goddard (screenplay), Andy Weir (book)',
#    u'Year': u'2015',
#    u'imdbID': u'tt3659388',
#    u'imdbRating': u'8.0',
#    u'imdbVotes': u'495,332'}),
#  (240,
#   {u'Actors': u'Anna Paquin, James Van Der Beek, Cloris Leachman, Mark Hamill',
#    u'Awards': u'1 win.',
#    u'Country': u'Japan',
#    u'Director': u'Hayao Miyazaki',
#    u'Genre': u'Animation, Adventure, Family',
#    u'Language': u'Japanese',
#    u'Metascore': u'N/A',
#    u'Plot': u'A young boy and a girl with a magic crystal must race against pirates and foreign agents in a search for a legendary floating castle.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTU4MTUyMTc3MV5BMl5BanBnXkFtZTYwOTg4Mzk5._V1_SX300.jpg',
#    u'Rated': u'PG',
#    u'Released': u'02 Aug 1986',
#    u'Response': u'True',
#    u'Runtime': u'125 min',
#    u'Title': u'Castle in the Sky',
#    u'Type': u'movie',
#    u'Writer': u'Hayao Miyazaki',
#    u'Year': u'1986',
#    u'imdbID': u'tt0092067',
#    u'imdbRating': u'8.1',
#    u'imdbVotes': u'101,429'}),
#  (241,
#   {u'Actors': u'Gregory Peck, Audrey Hepburn, Eddie Albert, Hartley Power',
#    u'Awards': u'Won 3 Oscars. Another 7 wins & 15 nominations.',
#    u'Country': u'USA',
#    u'Director': u'William Wyler',
#    u'Genre': u'Comedy, Romance',
#    u'Language': u'English, Italian, German',
#    u'Metascore': u'76',
#    u'Plot': u'A bored and sheltered princess escapes her guardians and falls in love with an American newsman in Rome.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTg1ODgzODA1Nl5BMl5BanBnXkFtZTcwNTI0MzU3Mg@@._V1_SX300.jpg',
#    u'Rated': u'NOT RATED',
#    u'Released': u'02 Sep 1953',
#    u'Response': u'True',
#    u'Runtime': u'118 min',
#    u'Title': u'Roman Holiday',
#    u'Type': u'movie',
#    u'Writer': u'Ian McLellan Hunter (screenplay), John Dighton (screenplay), Dalton Trumbo (screenplay), Dalton Trumbo (story)',
#    u'Year': u'1953',
#    u'imdbID': u'tt0046250',
#    u'imdbRating': u'8.1',
#    u'imdbVotes': u'102,328'}),
#  (242,
#   {u'Actors': u'Clint Eastwood, Marianne Koch, Gian Maria Volont\xe8, Wolfgang Lukschy',
#    u'Awards': u'1 win & 1 nomination.',
#    u'Country': u'Italy, Spain, West Germany',
#    u'Director': u'Sergio Leone',
#    u'Genre': u'Action, Drama, Western',
#    u'Language': u'Italian, Spanish',
#    u'Metascore': u'N/A',
#    u'Plot': u'A wandering gunfighter plays two rival families against each other in a town torn apart by greed, pride, and revenge.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTAzODAxMzg1MzZeQTJeQWpwZ15BbWU3MDgwMzE5ODk@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'18 Jan 1967',
#    u'Response': u'True',
#    u'Runtime': u'99 min',
#    u'Title': u'A Fistful of Dollars',
#    u'Type': u'movie',
#    u'Writer': u'Adriano Bolzoni (story), V\xedctor Andr\xe9s Catena (story), Sergio Leone (story), V\xedctor Andr\xe9s Catena (screenplay), Jaime Comas Gil (screenplay), Sergio Leone (screenplay)',
#    u'Year': u'1964',
#    u'imdbID': u'tt0058461',
#    u'imdbRating': u'8.0',
#    u'imdbVotes': u'150,943'}),
#  (243,
#   {u'Actors': u'Chris Pratt, Zoe Saldana, Dave Bautista, Vin Diesel',
#    u'Awards': u'Nominated for 2 Oscars. Another 48 wins & 92 nominations.',
#    u'Country': u'USA, UK',
#    u'Director': u'James Gunn',
#    u'Genre': u'Action, Adventure, Sci-Fi',
#    u'Language': u'English',
#    u'Metascore': u'76',
#    u'Plot': u'A group of intergalactic criminals are forced to work together to stop a fanatical warrior from taking control of the universe.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTAwMjU5OTgxNjZeQTJeQWpwZ15BbWU4MDUxNDYxODEx._V1_SX300.jpg',
#    u'Rated': u'PG-13',
#    u'Released': u'01 Aug 2014',
#    u'Response': u'True',
#    u'Runtime': u'121 min',
#    u'Title': u'Guardians of the Galaxy',
#    u'Type': u'movie',
#    u'Writer': u'James Gunn, Nicole Perlman, Dan Abnett (based on the Marvel comic book by), Andy Lanning (based on the Marvel comic book by)',
#    u'Year': u'2014',
#    u'imdbID': u'tt2015381',
#    u'imdbRating': u'8.1',
#    u'imdbVotes': u'701,014'}),
#  (244,
#   {u'Actors': u'Kristina Adolphson, B\xf6rje Ahlstedt, Pernilla Allwin, Kristian Almgren',
#    u'Awards': u'Won 4 Oscars. Another 19 wins & 10 nominations.',
#    u'Country': u'Sweden, France, West Germany',
#    u'Director': u'Ingmar Bergman',
#    u'Genre': u'Drama',
#    u'Language': u'Swedish, German, Yiddish, English',
#    u'Metascore': u'100',
#    u'Plot': u'Two young Swedish children experience the many comedies and tragedies of their family, the Ekdahls.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BOTUyODUwNjc0NV5BMl5BanBnXkFtZTcwMTk0MTcyMQ@@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'17 Dec 1982',
#    u'Response': u'True',
#    u'Runtime': u'188 min',
#    u'Title': u'Fanny and Alexander',
#    u'Type': u'movie',
#    u'Writer': u'Ingmar Bergman',
#    u'Year': u'1982',
#    u'imdbID': u'tt0083922',
#    u'imdbRating': u'8.1',
#    u'imdbVotes': u'43,998'}),
#  (245,
#   {u'Actors': u'Colin Firth, Helena Bonham Carter, Derek Jacobi, Robert Portal',
#    u'Awards': u'Won 4 Oscars. Another 101 wins & 190 nominations.',
#    u'Country': u'UK, USA, Australia',
#    u'Director': u'Tom Hooper',
#    u'Genre': u'Biography, Drama',
#    u'Language': u'English',
#    u'Metascore': u'88',
#    u'Plot': u'The story of King George VI of the United Kingdom of Great Britain and Northern Ireland, his impromptu ascension to the throne and the speech therapist who helped the unsure monarch become worthy of it.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMzU5MjEwMTg2Nl5BMl5BanBnXkFtZTcwNzM3MTYxNA@@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'25 Dec 2010',
#    u'Response': u'True',
#    u'Runtime': u'118 min',
#    u'Title': u"The King's Speech",
#    u'Type': u'movie',
#    u'Writer': u'David Seidler (screenplay)',
#    u'Year': u'2010',
#    u'imdbID': u'tt1504320',
#    u'imdbRating': u'8.0',
#    u'imdbVotes': u'510,889'}),
#  (246,
#   {u'Actors': u'Robert Downey Jr., Chris Evans, Mark Ruffalo, Chris Hemsworth',
#    u'Awards': u'Nominated for 1 Oscar. Another 34 wins & 75 nominations.',
#    u'Country': u'USA',
#    u'Director': u'Joss Whedon',
#    u'Genre': u'Action, Sci-Fi, Thriller',
#    u'Language': u'English, Russian',
#    u'Metascore': u'69',
#    u'Plot': u"Earth's mightiest heroes must come together and learn to fight as a team if they are to stop the mischievous Loki and his alien army from enslaving humanity.",
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTk2NTI1MTU4N15BMl5BanBnXkFtZTcwODg0OTY0Nw@@._V1_SX300.jpg',
#    u'Rated': u'PG-13',
#    u'Released': u'04 May 2012',
#    u'Response': u'True',
#    u'Runtime': u'143 min',
#    u'Title': u'The Avengers',
#    u'Type': u'movie',
#    u'Writer': u'Joss Whedon (screenplay), Zak Penn (story), Joss Whedon (story)',
#    u'Year': u'2012',
#    u'imdbID': u'tt0848228',
#    u'imdbRating': u'8.1',
#    u'imdbVotes': u'1,010,033'}),
#  (247,
#   {u'Actors': u'Harry Dean Stanton, Sam Berry, Bernhard Wicki, Dean Stockwell',
#    u'Awards': u'Nominated for 1 Golden Globe. Another 16 wins & 8 nominations.',
#    u'Country': u'West Germany, France, UK',
#    u'Director': u'Wim Wenders',
#    u'Genre': u'Drama',
#    u'Language': u'English',
#    u'Metascore': u'N/A',
#    u'Plot': u'Travis Henderson, an aimless drifter who has been missing for four years, wanders out of the desert and must reconnect with society, himself, his life, and his family.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BM2RjMmU3ZWItYzBlMy00ZmJkLWE5YzgtNTVkODdhOWM3NGZhXkEyXkFqcGdeQXVyNDA5Mjg5MjA@._V1_SX300.jpg',
#    u'Rated': u'R',
#    u'Released': u'19 Sep 1984',
#    u'Response': u'True',
#    u'Runtime': u'147 min',
#    u'Title': u'Paris, Texas',
#    u'Type': u'movie',
#    u'Writer': u'L.M. Kit Carson (adaptation), Sam Shepard',
#    u'Year': u'1984',
#    u'imdbID': u'tt0087884',
#    u'imdbRating': u'8.1',
#    u'imdbVotes': u'50,636'}),
#  (248,
#   {u'Actors': u'Aamir Khan, Gracy Singh, Rachel Shelley, Paul Blackthorne',
#    u'Awards': u'Nominated for 1 Oscar. Another 44 wins & 19 nominations.',
#    u'Country': u'India',
#    u'Director': u'Ashutosh Gowariker',
#    u'Genre': u'Adventure, Drama, Musical',
#    u'Language': u'Hindi, English, Awadhi, Urdu',
#    u'Metascore': u'84',
#    u'Plot': u'The people of a small village in Victorian India stake their future on a game of cricket against their ruthless British rulers.',
#    u'Poster': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNDYxNWUzZmYtOGQxMC00MTdkLTkxOTctYzkyOGIwNWQxZjhmXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SX300.jpg',
#    u'Rated': u'PG',
#    u'Released': u'08 May 2002',
#    u'Response': u'True',
#    u'Runtime': u'224 min',
#    u'Title': u'Lagaan: Once Upon a Time in India',
#    u'Type': u'movie',
#    u'Writer': u'Ashutosh Gowariker (story), Ashutosh Gowariker (screenplay), Kumar Dave (screenplay), Sanjay Dayma (screenplay), K.P. Saxena (dialogue)',
#    u'Year': u'2001',
#    u'imdbID': u'tt0169102',
#    u'imdbRating': u'8.2',
#    u'imdbVotes': u'73,792'})]

# %%
#lists to collect data
Rank=[]
Actors=[]
Awards=[]
Country=[]
Director=[]
Genre=[]
Language=[]
Metascore=[]
Plot=[]
Rated=[]
Released=[]
Response=[]
Runtime=[]
Title=[]
Type=[]
Writer=[]
Year=[]
imdbID=[]
imdbRating=[]
imdbVotes=[]
canRank=[]

# %%
for movie in movies3_plus_json:  
   if movie[0] == 103 or movie[0] == 188 or movie[0] == 237:
      print 'stop'
      continue
# Out:
# stop
# ok
# ok

# %%
for movie in movies3_plus_json:  
    if movie[0] == 103 or movie[0] == 188 or movie[0] == 237:
       print 'stop'
       continue
    
    Rank.append(movie[0])   
    Actors.append(movie[1]['Actors'])
    Awards.append(movie[1]['Awards'])
    Country.append(movie[1]['Country'])
    Director.append(movie[1]['Director'])
    Genre.append(movie[1]['Genre'])
    Language.append(movie[1]['Language'])
    Metascore.append(movie[1]['Metascore'])
    Plot.append(movie[1]['Plot'])
    Rated.append(movie[1]['Rated'])
    Released.append(movie[1]['Released'])
    Response.append(movie[1]['Response'])
    Runtime.append(movie[1]['Runtime'])
    Title.append(movie[1]['Title'])
    Type.append(movie[1]['Type'])
    Writer.append(movie[1]['Writer'])
    Year.append(movie[1]['Year'])
    imdbID.append(movie[1]['imdbID'])
    imdbRating.append(movie[1]['imdbRating'])
    imdbVotes.append(movie[1]['imdbVotes'])
# Out:
# stop
# stop
# stop

# %%
dictMovies2={'Ranking':Rank,
     'Actors':Actors,
     'Awards':Awards,
     'Country':Country,
     'Director':Director,
     'Genre':Genre,
     'Language':Language,
     'Metascore':Metascore,
     'Plot':Plot,
     'Rated':Rated,
     'Released':Released,
     'Response':Response,
     'Runtime':Runtime,
     'Title':Title,
     'Type':Type,
     'Writer':Writer,
     'Year':Year,
     'imdbID':imdbID,
     'imdbRating':imdbRating,
     'imdbVotes':imdbVotes}
movieData=pd.DataFrame(dictMovies2)

# %%
len(movieData)
# Out:
# 243

# %%
# for movie in movies2_plus_json:
#     movieName=str(movie[0])
#     print movieName      
#     movieTitle=movie[1]['Title']   
#     print movieTitle
#     movieGenre=movie[1]['Genre']
#     print movieGenre
#     movieRuntime=movie[1]['Runtime'].replace(' min', '')
#     print movieRuntime
#     print '\n'
# Out:
# 0
# The Shawshank Redemption
# Crime, Drama
# 142
#
#
# 1
# The Godfather
# Crime, Drama
# 175
#
#
# 2
# The Godfather: Part II
# Crime, Drama
# 202
#
#
# 3
# The Dark Knight
# Action, Crime, Drama
# 152
#
#
# 4
# 12 Angry Men
# Crime, Drama
# 96
#
#
# 5
# Schindler's List
# Biography, Drama, History
# 195
#
#
# 6
# Pulp Fiction
# Crime, Drama
# 154
#
#
# 7
# The Lord of the Rings: The Return of the King
# Action, Adventure, Drama
# 201
#
#
# 8
# The Good, the Bad and the Ugly
# Western
# 161
#
#
# 9
# Fight Club
# Drama
# 139
#
#
# 10
# The Lord of the Rings: The Fellowship of the Ring
# Action, Adventure, Drama
# 178
#
#
# 11
# Star Wars: Episode V - The Empire Strikes Back
# Action, Adventure, Fantasy
# 124
#
#
# 12
# Forrest Gump
# Comedy, Drama
# 142
#
#
# 13
# Inception
# Action, Adventure, Sci-Fi
# 148
#
#
# 14
# The Lord of the Rings: The Two Towers
# Adventure, Drama, Fantasy
# 179
#
#
# 15
# One Flew Over the Cuckoo's Nest
# Drama
# 133
#
#
# 16
# Goodfellas
# Biography, Crime, Drama
# 146
#
#
# 17
# The Matrix
# Action, Sci-Fi
# 136
#
#
# 18
# Seven Samurai
# Action, Adventure, Drama
# 207
#
#
# 19
# Star Wars: Episode IV - A New Hope
# Action, Adventure, Fantasy
# 121
#
#
# 20
# City of God
# Crime, Drama
# 130
#
#
# 21
# Se7en
# Crime, Drama, Mystery
# 127
#
#
# 22
# The Silence of the Lambs
# Crime, Drama, Thriller
# 118
#
#
# 23
# It's a Wonderful Life
# Drama, Family, Fantasy
# 130
#
#
# 24
# The Usual Suspects
# Crime, Drama, Mystery
# 106
#
#
# 25
# Life Is Beautiful
# Comedy, Drama, War
# 116
#
#
# 26
# Léon: The Professional
# Crime, Drama, Thriller
# 110
#
#
# 27
# Spirited Away
# Animation, Adventure, Family
# 125
#
#
# 28
# Saving Private Ryan
# Action, Drama, War
# 169
#
#
# 29
# Once Upon a Time in the West
# Western
# 175
#
#
# 30
# American History X
# Crime, Drama
# 119
#
#
# 31
# Interstellar
# Adventure, Drama, Sci-Fi
# 169
#
#
# 32
# Casablanca
# Drama, Romance, War
# 102
#
#
# 33
# Psycho
# Horror, Mystery, Thriller
# 109
#
#
# 34
# City Lights
# Comedy, Drama, Romance
# 87
#
#
# 35
# Raiders of the Lost Ark
# Action, Adventure
# 115
#
#
# 36
# The Green Mile
# Crime, Drama, Fantasy
# 189
#
#
# 37
# The Intouchables
# Biography, Comedy, Drama
# 112
#
#
# 38
# Modern Times
# Comedy, Drama, Family
# 87
#
#
# 39
# Rear Window
# Mystery, Thriller
# 112
#
#
# 40
# Terminator 2: Judgment Day
# Action, Sci-Fi, Thriller
# 137
#
#
# 41
# The Departed
# Crime, Drama, Thriller
# 151
#
#
# 42
# The Pianist
# Biography, Drama, War
# 150
#
#
# 43
# Back to the Future
# Adventure, Comedy, Sci-Fi
# 116
#
#
# 44
# Whiplash
# Drama, Music
# 107
#
#
# 45
# Gladiator
# Action, Adventure, Drama
# 155
#
#
# 46
# Memento
# Mystery, Thriller
# 113
#
#
# 47
# Apocalypse Now
# Drama, War
# 153
#
#
# 48
# The Prestige
# Drama, Mystery, Sci-Fi
# 130
#
#
# 49
# The Lion King
# Animation, Adventure, Drama
# 89

# %%
movieData.to_csv('movieData.csv', encoding='utf-8')
